# %%
# Imports
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet121, EfficientNetB3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold
import pickle
import time
import collections
from sklearn.metrics import (
    accuracy_score, roc_auc_score, precision_score, recall_score,
    f1_score, confusion_matrix, roc_curve
)
from skopt import gp_minimize
from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args
# Out:
# 2025-05-07 14:46:00.319176: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746629160.499594      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746629160.553436      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Use Mixed Precision (save VRAM)
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")
print("mixed precision enabled.")
# Out:
# mixed precision enabled.

# %%
# Load Preprocessed Data --- balanced checked
DATA_PATH = "/kaggle/input/preprocessed-mammo-splits"  
train = np.load(os.path.join(DATA_PATH, "train_data.npz"))
val = np.load(os.path.join(DATA_PATH, "val_data.npz"))
test = np.load(os.path.join(DATA_PATH, "test_data.npz"))

X_train, y_train = train["X"], train["y"]
X_val, y_val = val["X"], val["y"]
X_test, y_test = test["X"], test["y"]

# %%
# Compute Class Weights
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))
print("Class Weights:", class_weight_dict)
# Out:
# Class Weights: {0: 1.1308917197452228, 1: 0.8962645128722867}

# %%
# Expand dims because TF expects (H, W, 1) from (H, W)
X_train = X_train[..., np.newaxis].astype("float32")
X_val = X_val[..., np.newaxis].astype("float32")
X_test = X_test[..., np.newaxis].astype("float32")

# %%
# Enhanced data augmentation
def convert_to_rgb(image, label):
    image_rgb = tf.image.grayscale_to_rgb(image)  
    image_rgb = tf.squeeze(image_rgb) 
    return image_rgb, label

# %%
def augment(image, label):
    # Random rotation (0-15 degrees)
    angle = tf.random.uniform([], -0.26, 0.26)  # ~15 degrees in radians
    image = tf.image.rot90(image, k=tf.cast(angle * 2 / 3.14159, tf.int32))
    
    # Random flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    # Random brightness/contrast adjustments
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    
    # Random zoom (crop and resize)
    zoom_factor = tf.random.uniform([], 0.8, 1.0, dtype=tf.float32)
    h, w = tf.shape(image)[0], tf.shape(image)[1]
    crop_size_h = tf.cast(tf.cast(h, tf.float32) * zoom_factor, tf.int32)
    crop_size_w = tf.cast(tf.cast(w, tf.float32) * zoom_factor, tf.int32)
    
    # Ensure crop dimensions don't exceed image dimensions
    crop_size_h = tf.minimum(crop_size_h, h)
    crop_size_w = tf.minimum(crop_size_w, w)
    
    image = tf.image.random_crop(image, size=[crop_size_h, crop_size_w, 3])
    image = tf.image.resize(image, [224, 224])
    
    return image, label

# %%
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

# Create datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Apply preprocessing and augmentation
train_ds = (
    train_ds.shuffle(1024)
    .map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .map(augment, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

val_ds = (
    val_ds.map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = (
    test_ds.map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
# Out:
# I0000 00:00:1746629208.308839      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
# Bayesian Optimization Space
bayes_space = [
    Real(1e-5, 1e-3, "log-uniform", name="learning_rate"),
    Integer(128, 1024, name="dense_units_1"),
    Integer(64, 512, name="dense_units_2"),
    Real(0.2, 0.7, name="dropout_rate_1"),
    Real(0.1, 0.5, name="dropout_rate_2"),
    Integer(10, 50, name="unfreeze_layers")
]

# %%
def build_tuned_model(base_model_fn, hyperparams, name="model"):
    base_model = base_model_fn(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
    base_model.trainable = False
    
    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    
    x = Dense(hyperparams["dense_units_1"], activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(hyperparams["dropout_rate_1"])(x)
    
    x = Dense(hyperparams["dense_units_2"], activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(hyperparams["dropout_rate_2"])(x)
    
    outputs = Dense(1, activation='sigmoid', dtype='float32')(x)
    
    model = Model(inputs, outputs, name=name)

    model.compile(
        optimizer=Adam(learning_rate=hyperparams["learning_rate"]),
        loss='binary_crossentropy',
        metrics=[
            'accuracy', 
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model, base_model

# %%
def unfreeze_tuned_model(model, base_model, hyperparams):
    base_model.trainable = True
    
    for layer in base_model.layers[:-hyperparams["unfreeze_layers"]]:
        layer.trainable = False
    
    model.compile(
        optimizer=Adam(learning_rate=hyperparams["learning_rate"]/10),
        loss='binary_crossentropy',
        metrics=[
            'accuracy', 
            tf.keras.metrics.AUC(name='auc',dtype=tf.float32),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model

# %%
@use_named_args(bayes_space)
def objective_function(**params):
    hyperparams = {
        "learning_rate": params["learning_rate"],
        "dense_units_1": params["dense_units_1"],
        "dense_units_2": params["dense_units_2"],
        "dropout_rate_1": params["dropout_rate_1"],
        "dropout_rate_2": params["dropout_rate_2"],
        "unfreeze_layers": params["unfreeze_layers"]
    }
    
    model_fn = DenseNet121
    
    model, base_model = build_tuned_model(model_fn, hyperparams, name="bayes_opt_model")
    
    tuning_callbacks = [
        EarlyStopping(monitor='val_auc', patience=3, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)
    ]
    
    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=3,
        class_weight=class_weight_dict,
        callbacks=tuning_callbacks,
        verbose=0
    )
    
    model = unfreeze_tuned_model(model, base_model, hyperparams)
    model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=3,
        class_weight=class_weight_dict,
        callbacks=tuning_callbacks,
        verbose=0
    )
    
    val_results = model.evaluate(val_ds, verbose=0,return_dict=True)
    print("Evaluation metrics:", val_results.keys())
    val_auc = val_results['auc']
    
    return -val_auc

# %%
def run_bayesian_optimization(model_fn, n_calls=5):
    print(f"Starting Bayesian Optimization with {n_calls} iterations...")
    
    result = gp_minimize(
        objective_function,
        bayes_space,
        n_calls=n_calls,
        n_initial_points=5,
        verbose=True,
        n_jobs=1,
        acq_func="EI",  
        acq_optimizer="sampling"
    )
    
    best_params = {
        "learning_rate": result.x[0],
        "dense_units_1": result.x[1],
        "dense_units_2": result.x[2],
        "dropout_rate_1": result.x[3],
        "dropout_rate_2": result.x[4],
        "unfreeze_layers": result.x[5]
    }
    
    print("\nBest parameters found:")
    for param, value in best_params.items():
        print(f"{param}: {value}")
    
    print(f"Best validation AUC: {-result.fun:.4f}")
    
    return best_params

# %%
def run_hyperparameter_optimization(model_fn, name, n_calls=5):
    print(f"\n{'='*50}")
    print(f"Bayesian optimization for {name}...")
    print(f"{'='*50}")
    
    best_params = run_bayesian_optimization(model_fn, n_calls=n_calls)
    model, base_model = build_tuned_model(model_fn, best_params, name=f"{name}_bayes_opt")
    
    with open(f"{name}_best_hyperparams.pkl", "wb") as f:
        pickle.dump(best_params, f)
    print(f"Saved hyperparameters: {name}_best_hyperparams.pkl")
    
    return model, base_model, best_params

# %%
def find_optimal_threshold(model, ds):
    # Get predictions and true labels
    pred = model.predict(ds)
    true = np.concatenate([y for x, y in ds], axis=0)
    
    # Calculate ROC curve
    fpr, tpr, thresholds = roc_curve(true, pred)
    
    # Find optimal threshold using Youden's J statistic
    j_scores = tpr - fpr
    optimal_idx = np.argmax(j_scores)
    optimal_threshold = thresholds[optimal_idx]
    
    print(f"Optimal threshold: {optimal_threshold:.4f}")
    return optimal_threshold

# %%
def evaluate_with_threshold(model, ds, threshold=0.5):
    # Get predictions
    pred = model.predict(ds)
    
    # Get true labels
    true = np.concatenate([y for x, y in ds], axis=0)
    
    # Apply threshold
    pred_binary = (pred > threshold).astype(int)
    
    # Calculate metrics
    acc = accuracy_score(true, pred_binary)
    auc = roc_auc_score(true, pred)
    precision = precision_score(true, pred_binary)
    recall = recall_score(true, pred_binary)
    f1 = f1_score(true, pred_binary)
    cm = confusion_matrix(true, pred_binary)
    
    # Calculate specificity
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    
    print(f"\n{'='*30} Evaluation Results {'='*30}")
    print(f"Accuracy: {acc:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Confusion Matrix:\n{cm}")
    print(f"{'='*78}")
    
    return {
        'accuracy': acc,
        'auc': auc,
        'precision': precision,
        'recall': recall,
        'specificity': specificity,
        'f1': f1,
        'confusion_matrix': cm,
        'predictions': pred,
        'threshold': threshold
    }

# %%
# train_model_with_hyperopt function
def train_model_with_hyperopt(name, model_fn, n_calls=5):
    print(f"\n{'='*50}")
    print(f"Training {name} with Bayesian optimization...")
    print(f"{'='*50}")
    
    model, base_model, best_params = run_hyperparameter_optimization(
        model_fn, 
        name,
        n_calls=n_calls
    )
    
    callbacks = [
        EarlyStopping(patience=15, restore_best_weights=True, verbose=1),
        ModelCheckpoint(
            f"/kaggle/working/models/{name}_phase1.keras",
            save_best_only=True,
            monitor='val_auc',
            mode='max',
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]
    
    # Phase 1: Frozen base training
    print("Initial training with frozen base layers...")
    history1 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,
        class_weight=class_weight_dict,
        callbacks=callbacks,
        verbose=2
    )
    
    # Phase 2: Fine-tuning
    print("\nFine-tuning with unfrozen layers...")
    model = unfreeze_tuned_model(model, base_model, best_params)
    callbacks[1] = ModelCheckpoint(
        f"/kaggle/working/models/{name}_phase2.keras",
        save_best_only=True,
        monitor='val_auc',
        mode='max',
        verbose=1
    )
    
    history2 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,
        class_weight=class_weight_dict,
        callbacks=callbacks,
        verbose=2
    )
    
    # Threshold optimization and evaluation
    print("\nOptimizing classification threshold...")
    optimal_threshold = find_optimal_threshold(model, val_ds)
    
    print("\nFinal evaluation on test set:")
    test_results = evaluate_with_threshold(model, test_ds, threshold=optimal_threshold)
    
    # Save model and results
    model.save(f"{name}_trained_model.h5")
    print(f"Saved model: {name}_trained_model.h5")
    
    combined_history = {
        'phase1': history1.history,
        'phase2': history2.history,
        'best_hyperparams': best_params,
        'test_results': test_results,
        'optimal_threshold': optimal_threshold
    }
    
    with open(f"{name}_history.pkl", "wb") as f:
        pickle.dump(combined_history, f)
    
    return model, test_results

# %%
# Initialize storage
model_results = {}
history_dict = {}
all_trained_models = {}

# %%
models_to_train = {
    # "VGG16": VGG16
    # "ResNet50": ResNet50
    "DenseNet121": DenseNet121
    # "EfficientNetB3": EfficientNetB3  
}

# %%
for name, model_fn in models_to_train.items():
    print(f"\n{'='*50}")
    print(f"Training {name}...")
    print(f"{'='*50}")
    
    # Hyperparameter Optimization
    print("Running Bayesian optimization...")
    model, base_model, best_params = run_hyperparameter_optimization(model_fn, name)
    
    # Phase 1: Frozen Base Training
    print("\nPhase 1: Initial training with frozen base layers")
    phase1_callbacks = [
        EarlyStopping(monitor='val_auc', patience=15, restore_best_weights=True),
        ModelCheckpoint(f"{name}_phase1.keras", monitor='val_auc', save_best_only=True, mode='max'),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
    ]
    
    history1 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,
        class_weight=class_weight_dict,
        callbacks=phase1_callbacks,
        verbose=2
    )
    
    # Phase 2: Fine-tuning
    print("\nPhase 2: Fine-tuning with unfrozen layers")
    model = unfreeze_tuned_model(model, base_model, best_params)
    
    phase2_callbacks = [
        EarlyStopping(monitor='val_auc', patience=10, restore_best_weights=True),
        ModelCheckpoint(f"{name}_phase2.keras", monitor='val_auc', save_best_only=True, mode='max'),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-7)
    ]
    
    history2 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,
        class_weight=class_weight_dict,
        callbacks=phase2_callbacks,
        verbose=2
    )
    
    # Threshold Optimization & Evaluation
    print("\nOptimizing classification threshold...")
    optimal_threshold = find_optimal_threshold(model, val_ds)
    
    print("\nFinal Evaluation:")
    test_results = evaluate_with_threshold(model, test_ds, threshold=optimal_threshold)
    model_results[name] = test_results
    
    # Save artifacts
    model.save(f"{name}_trained_model.keras")
    history_dict[name] = {
        'phase1': history1.history,
        'phase2': history2.history,
        'best_params': best_params,
        'optimal_threshold': optimal_threshold
    }
    with open(f"{name}_history.pkl", "wb") as f:
        pickle.dump(history_dict[name], f)

# ============== Results Summary ==============        
print("\n\n=== Final Results Summary ===")
for model_name, results in model_results.items():
    print(f"\n{model_name}:")
    print(f"AUC: {results['auc']:.4f} | Accuracy: {results['accuracy']:.4f}")
    print(f"Precision: {results['precision']:.4f} | Recall: {results['recall']:.4f}")
    print(f"F1: {results['f1']:.4f} | Specificity: {results['specificity']:.4f}")
    print(f"Optimal Threshold: {history_dict[model_name]['optimal_threshold']:.4f}")
# Out:
# ==================================================
# Training DenseNet121...
# ==================================================
# Running Bayesian optimization...
#
# ==================================================
# Bayesian optimization for DenseNet121...
# ==================================================
# Starting Bayesian Optimization with 5 iterations...
# Iteration No: 1 started. Evaluating function at random point.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1746629250.117686      91 service.cc:148] XLA service 0x78162c022e20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1746629250.118287      91 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1746629253.341493      91 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1746629266.774082      91 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Evaluation metrics: dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 360.3207
# Function value obtained: -0.9672
# Current minimum: -0.9672
# Iteration No: 2 started. Evaluating function at random point.
# Evaluation metrics: dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 354.4820
# Function value obtained: -0.8979
# Current minimum: -0.9672
# Iteration No: 3 started. Evaluating function at random point.
# Evaluation metrics: dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 361.6143
# Function value obtained: -0.8391
# Current minimum: -0.9672
# Iteration No: 4 started. Evaluating function at random point.
# Evaluation metrics: dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 353.3848
# Function value obtained: -0.9558
# Current minimum: -0.9672
# Iteration No: 5 started. Evaluating function at random point.
# Evaluation metrics: dict_keys(['accuracy', 'auc', 'loss', 'precision', 'recall'])
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 360.9909
# Function value obtained: -0.9937
# Current minimum: -0.9937
#
# Best parameters found:
# learning_rate: 0.0003540737499708119
# dense_units_1: 660
# dense_units_2: 477
# dropout_rate_1: 0.5038580819261428
# dropout_rate_2: 0.25723647240598374
# unfreeze_layers: 43
# Best validation AUC: 0.9937
# Saved hyperparameters: DenseNet121_best_hyperparams.pkl
#
# Phase 1: Initial training with frozen base layers
# Epoch 1/30
# 555/555 - 103s - 185ms/step - accuracy: 0.7530 - auc: 0.8384 - loss: 0.5169 - precision: 0.7991 - recall: 0.7445 - val_accuracy: 0.8545 - val_auc: 0.9355 - val_loss: 0.3198 - val_precision: 0.8683 - val_recall: 0.8713 - learning_rate: 3.5407e-04
# Epoch 2/30
# 555/555 - 33s - 59ms/step - accuracy: 0.8256 - auc: 0.9123 - loss: 0.3767 - precision: 0.8565 - recall: 0.8256 - val_accuracy: 0.8832 - val_auc: 0.9534 - val_loss: 0.2819 - val_precision: 0.9213 - val_recall: 0.8644 - learning_rate: 3.5407e-04
# Epoch 3/30
# 555/555 - 32s - 58ms/step - accuracy: 0.8532 - auc: 0.9357 - loss: 0.3231 - precision: 0.8815 - recall: 0.8512 - val_accuracy: 0.9027 - val_auc: 0.9701 - val_loss: 0.2234 - val_precision: 0.9173 - val_recall: 0.9073 - learning_rate: 3.5407e-04
# Epoch 4/30
# 555/555 - 33s - 59ms/step - accuracy: 0.8712 - auc: 0.9490 - loss: 0.2880 - precision: 0.8959 - recall: 0.8702 - val_accuracy: 0.8989 - val_auc: 0.9723 - val_loss: 0.2299 - val_precision: 0.9497 - val_recall: 0.8644 - learning_rate: 3.5407e-04
# Epoch 5/30
# 555/555 - 32s - 58ms/step - accuracy: 0.8844 - auc: 0.9565 - loss: 0.2665 - precision: 0.9079 - recall: 0.8822 - val_accuracy: 0.9199 - val_auc: 0.9785 - val_loss: 0.1882 - val_precision: 0.9156 - val_recall: 0.9434 - learning_rate: 3.5407e-04
# Epoch 6/30
# 555/555 - 31s - 57ms/step - accuracy: 0.8852 - auc: 0.9578 - loss: 0.2627 - precision: 0.9076 - recall: 0.8841 - val_accuracy: 0.9113 - val_auc: 0.9751 - val_loss: 0.2005 - val_precision: 0.9190 - val_recall: 0.9222 - learning_rate: 3.5407e-04
# Epoch 7/30
# 555/555 - 32s - 58ms/step - accuracy: 0.8990 - auc: 0.9652 - loss: 0.2385 - precision: 0.9176 - recall: 0.8996 - val_accuracy: 0.9170 - val_auc: 0.9821 - val_loss: 0.1851 - val_precision: 0.9531 - val_recall: 0.8953 - learning_rate: 3.5407e-04
# Epoch 8/30
# 555/555 - 32s - 58ms/step - accuracy: 0.9015 - auc: 0.9666 - loss: 0.2339 - precision: 0.9190 - recall: 0.9030 - val_accuracy: 0.9308 - val_auc: 0.9853 - val_loss: 0.1568 - val_precision: 0.9357 - val_recall: 0.9405 - learning_rate: 3.5407e-04
# Epoch 9/30
# 555/555 - 31s - 57ms/step - accuracy: 0.9075 - auc: 0.9710 - loss: 0.2183 - precision: 0.9268 - recall: 0.9058 - val_accuracy: 0.9132 - val_auc: 0.9811 - val_loss: 0.1900 - val_precision: 0.9578 - val_recall: 0.8833 - learning_rate: 3.5407e-04
# Epoch 10/30
# 555/555 - 32s - 58ms/step - accuracy: 0.9080 - auc: 0.9714 - loss: 0.2166 - precision: 0.9240 - recall: 0.9098 - val_accuracy: 0.9451 - val_auc: 0.9885 - val_loss: 0.1420 - val_precision: 0.9503 - val_recall: 0.9514 - learning_rate: 3.5407e-04
# Epoch 11/30
# 555/555 - 31s - 56ms/step - accuracy: 0.9160 - auc: 0.9749 - loss: 0.2026 - precision: 0.9337 - recall: 0.9143 - val_accuracy: 0.9394 - val_auc: 0.9849 - val_loss: 0.1540 - val_precision: 0.9371 - val_recall: 0.9554 - learning_rate: 3.5407e-04
# Epoch 12/30
# 555/555 - 31s - 56ms/step - accuracy: 0.9181 - auc: 0.9762 - loss: 0.1974 - precision: 0.9334 - recall: 0.9186 - val_accuracy: 0.9438 - val_auc: 0.9883 - val_loss: 0.1400 - val_precision: 0.9396 - val_recall: 0.9611 - learning_rate: 3.5407e-04
# Epoch 13/30
# 555/555 - 32s - 58ms/step - accuracy: 0.9252 - auc: 0.9782 - loss: 0.1881 - precision: 0.9401 - recall: 0.9249 - val_accuracy: 0.9426 - val_auc: 0.9885 - val_loss: 0.1376 - val_precision: 0.9380 - val_recall: 0.9605 - learning_rate: 3.5407e-04
# Epoch 14/30
# 555/555 - 31s - 56ms/step - accuracy: 0.9242 - auc: 0.9787 - loss: 0.1865 - precision: 0.9372 - recall: 0.9262 - val_accuracy: 0.9333 - val_auc: 0.9861 - val_loss: 0.1493 - val_precision: 0.9420 - val_recall: 0.9382 - learning_rate: 3.5407e-04
# Epoch 15/30
# 555/555 - 32s - 57ms/step - accuracy: 0.9225 - auc: 0.9784 - loss: 0.1875 - precision: 0.9379 - recall: 0.9222 - val_accuracy: 0.9416 - val_auc: 0.9875 - val_loss: 0.1438 - val_precision: 0.9589 - val_recall: 0.9354 - learning_rate: 3.5407e-04
# Epoch 16/30
# 555/555 - 32s - 58ms/step - accuracy: 0.9244 - auc: 0.9790 - loss: 0.1846 - precision: 0.9386 - recall: 0.9249 - val_accuracy: 0.9547 - val_auc: 0.9918 - val_loss: 0.1177 - val_precision: 0.9658 - val_recall: 0.9525 - learning_rate: 3.5407e-04
# Epoch 17/30
# 555/555 - 33s - 59ms/step - accuracy: 0.9284 - auc: 0.9802 - loss: 0.1797 - precision: 0.9426 - recall: 0.9281 - val_accuracy: 0.9550 - val_auc: 0.9919 - val_loss: 0.1173 - val_precision: 0.9669 - val_recall: 0.9519 - learning_rate: 3.5407e-04
# Epoch 18/30
# 555/555 - 31s - 56ms/step - accuracy: 0.9235 - auc: 0.9791 - loss: 0.1849 - precision: 0.9378 - recall: 0.9241 - val_accuracy: 0.9407 - val_auc: 0.9904 - val_loss: 0.1451 - val_precision: 0.9756 - val_recall: 0.9165 - learning_rate: 3.5407e-04
# Epoch 19/30
# 555/555 - 31s - 57ms/step - accuracy: 0.9288 - auc: 0.9814 - loss: 0.1740 - precision: 0.9447 - recall: 0.9266 - val_accuracy: 0.9518 - val_auc: 0.9899 - val_loss: 0.1294 - val_precision: 0.9439 - val_recall: 0.9714 - learning_rate: 3.5407e-04
# Epoch 20/30
# 555/555 - 31s - 56ms/step - accuracy: 0.9304 - auc: 0.9817 - loss: 0.1727 - precision: 0.9437 - recall: 0.9308 - val_accuracy: 0.9445 - val_auc: 0.9893 - val_loss: 0.1350 - val_precision: 0.9363 - val_recall: 0.9662 - learning_rate: 3.5407e-04
# Epoch 21/30
# 555/555 - 32s - 58ms/step - accuracy: 0.9293 - auc: 0.9815 - loss: 0.1729 - precision: 0.9439 - recall: 0.9285 - val_accuracy: 0.9553 - val_auc: 0.9932 - val_loss: 0.1104 - val_precision: 0.9647 - val_recall: 0.9548 - learning_rate: 3.5407e-04
# Epoch 22/30
# 555/555 - 31s - 56ms/step - accuracy: 0.9299 - auc: 0.9810 - loss: 0.1755 - precision: 0.9446 - recall: 0.9288 - val_accuracy: 0.9464 - val_auc: 0.9904 - val_loss: 0.1249 - val_precision: 0.9453 - val_recall: 0.9594 - learning_rate: 3.5407e-04
# Epoch 23/30
# 555/555 - 31s - 57ms/step - accuracy: 0.9331 - auc: 0.9835 - loss: 0.1637 - precision: 0.9455 - recall: 0.9339 - val_accuracy: 0.9582 - val_auc: 0.9922 - val_loss: 0.1115 - val_precision: 0.9612 - val_recall: 0.9640 - learning_rate: 3.5407e-04
# Epoch 24/30
# 555/555 - 42s - 76ms/step - accuracy: 0.9349 - auc: 0.9831 - loss: 0.1648 - precision: 0.9476 - recall: 0.9351 - val_accuracy: 0.9601 - val_auc: 0.9940 - val_loss: 0.1082 - val_precision: 0.9466 - val_recall: 0.9840 - learning_rate: 3.5407e-04
# Epoch 25/30
# 555/555 - 32s - 57ms/step - accuracy: 0.9337 - auc: 0.9835 - loss: 0.1639 - precision: 0.9473 - recall: 0.9330 - val_accuracy: 0.9547 - val_auc: 0.9939 - val_loss: 0.1046 - val_precision: 0.9718 - val_recall: 0.9462 - learning_rate: 3.5407e-04
# Epoch 26/30
# 555/555 - 32s - 57ms/step - accuracy: 0.9294 - auc: 0.9820 - loss: 0.1706 - precision: 0.9417 - recall: 0.9311 - val_accuracy: 0.9483 - val_auc: 0.9923 - val_loss: 0.1137 - val_precision: 0.9480 - val_recall: 0.9600 - learning_rate: 3.5407e-04
# Epoch 27/30
# 555/555 - 32s - 57ms/step - accuracy: 0.9336 - auc: 0.9831 - loss: 0.1653 - precision: 0.9473 - recall: 0.9329 - val_accuracy: 0.9541 - val_auc: 0.9935 - val_loss: 0.1112 - val_precision: 0.9762 - val_recall: 0.9405 - learning_rate: 3.5407e-04
# Epoch 28/30
# 555/555 - 33s - 59ms/step - accuracy: 0.9377 - auc: 0.9850 - loss: 0.1558 - precision: 0.9497 - recall: 0.9379 - val_accuracy: 0.9611 - val_auc: 0.9950 - val_loss: 0.0939 - val_precision: 0.9716 - val_recall: 0.9582 - learning_rate: 3.5407e-04
# Epoch 29/30
# 555/555 - 31s - 56ms/step - accuracy: 0.9382 - auc: 0.9846 - loss: 0.1580 - precision: 0.9500 - recall: 0.9385 - val_accuracy: 0.9451 - val_auc: 0.9887 - val_loss: 0.1355 - val_precision: 0.9354 - val_recall: 0.9685 - learning_rate: 3.5407e-04
# Epoch 30/30
# 555/555 - 41s - 73ms/step - accuracy: 0.9355 - auc: 0.9845 - loss: 0.1580 - precision: 0.9493 - recall: 0.9342 - val_accuracy: 0.9279 - val_auc: 0.9831 - val_loss: 0.1669 - val_precision: 0.9247 - val_recall: 0.9479 - learning_rate: 3.5407e-04
#
# Phase 2: Fine-tuning with unfrozen layers
# Epoch 1/50
# 555/555 - 124s - 223ms/step - accuracy: 0.9129 - auc: 0.9721 - loss: 0.2184 - precision: 0.9220 - recall: 0.9220 - val_accuracy: 0.9550 - val_auc: 0.9933 - val_loss: 0.1040 - val_precision: 0.9558 - val_recall: 0.9640 - learning_rate: 3.5407e-05
# Epoch 2/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9335 - auc: 0.9831 - loss: 0.1648 - precision: 0.9460 - recall: 0.9342 - val_accuracy: 0.9729 - val_auc: 0.9968 - val_loss: 0.0718 - val_precision: 0.9727 - val_recall: 0.9788 - learning_rate: 3.5407e-05
# Epoch 3/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9447 - auc: 0.9881 - loss: 0.1380 - precision: 0.9547 - recall: 0.9457 - val_accuracy: 0.9777 - val_auc: 0.9985 - val_loss: 0.0576 - val_precision: 0.9867 - val_recall: 0.9731 - learning_rate: 3.5407e-05
# Epoch 4/50
# 555/555 - 34s - 62ms/step - accuracy: 0.9578 - auc: 0.9920 - loss: 0.1122 - precision: 0.9668 - recall: 0.9572 - val_accuracy: 0.9802 - val_auc: 0.9986 - val_loss: 0.0502 - val_precision: 0.9850 - val_recall: 0.9794 - learning_rate: 3.5407e-05
# Epoch 5/50
# 555/555 - 34s - 62ms/step - accuracy: 0.9584 - auc: 0.9923 - loss: 0.1092 - precision: 0.9661 - recall: 0.9591 - val_accuracy: 0.9888 - val_auc: 0.9993 - val_loss: 0.0387 - val_precision: 0.9920 - val_recall: 0.9880 - learning_rate: 3.5407e-05
# Epoch 6/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9677 - auc: 0.9949 - loss: 0.0892 - precision: 0.9753 - recall: 0.9666 - val_accuracy: 0.9869 - val_auc: 0.9995 - val_loss: 0.0355 - val_precision: 0.9914 - val_recall: 0.9851 - learning_rate: 3.5407e-05
# Epoch 7/50
# 555/555 - 35s - 63ms/step - accuracy: 0.9690 - auc: 0.9953 - loss: 0.0849 - precision: 0.9748 - recall: 0.9694 - val_accuracy: 0.9898 - val_auc: 0.9998 - val_loss: 0.0293 - val_precision: 0.9971 - val_recall: 0.9846 - learning_rate: 3.5407e-05
# Epoch 8/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9702 - auc: 0.9957 - loss: 0.0803 - precision: 0.9783 - recall: 0.9681 - val_accuracy: 0.9920 - val_auc: 0.9997 - val_loss: 0.0252 - val_precision: 0.9937 - val_recall: 0.9920 - learning_rate: 3.5407e-05
# Epoch 9/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9745 - auc: 0.9965 - loss: 0.0722 - precision: 0.9802 - recall: 0.9740 - val_accuracy: 0.9907 - val_auc: 0.9998 - val_loss: 0.0248 - val_precision: 0.9942 - val_recall: 0.9891 - learning_rate: 3.5407e-05
# Epoch 10/50
# 555/555 - 35s - 63ms/step - accuracy: 0.9787 - auc: 0.9973 - loss: 0.0613 - precision: 0.9833 - recall: 0.9785 - val_accuracy: 0.9939 - val_auc: 0.9999 - val_loss: 0.0180 - val_precision: 0.9932 - val_recall: 0.9960 - learning_rate: 3.5407e-05
# Epoch 11/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9809 - auc: 0.9977 - loss: 0.0566 - precision: 0.9844 - recall: 0.9812 - val_accuracy: 0.9952 - val_auc: 0.9999 - val_loss: 0.0172 - val_precision: 0.9971 - val_recall: 0.9943 - learning_rate: 3.5407e-05
# Epoch 12/50
# 555/555 - 34s - 62ms/step - accuracy: 0.9798 - auc: 0.9978 - loss: 0.0557 - precision: 0.9859 - recall: 0.9777 - val_accuracy: 0.9949 - val_auc: 0.9999 - val_loss: 0.0155 - val_precision: 0.9949 - val_recall: 0.9960 - learning_rate: 3.5407e-05
# Epoch 13/50
# 555/555 - 37s - 66ms/step - accuracy: 0.9819 - auc: 0.9976 - loss: 0.0550 - precision: 0.9841 - recall: 0.9833 - val_accuracy: 0.9974 - val_auc: 1.0000 - val_loss: 0.0103 - val_precision: 0.9983 - val_recall: 0.9971 - learning_rate: 3.5407e-05
# Epoch 14/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9841 - auc: 0.9982 - loss: 0.0480 - precision: 0.9871 - recall: 0.9844 - val_accuracy: 0.9971 - val_auc: 1.0000 - val_loss: 0.0103 - val_precision: 0.9971 - val_recall: 0.9977 - learning_rate: 3.5407e-05
# Epoch 15/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9842 - auc: 0.9987 - loss: 0.0440 - precision: 0.9870 - recall: 0.9846 - val_accuracy: 0.9968 - val_auc: 1.0000 - val_loss: 0.0107 - val_precision: 0.9989 - val_recall: 0.9954 - learning_rate: 3.5407e-05
# Epoch 16/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9849 - auc: 0.9985 - loss: 0.0430 - precision: 0.9881 - recall: 0.9848 - val_accuracy: 0.9955 - val_auc: 1.0000 - val_loss: 0.0108 - val_precision: 0.9949 - val_recall: 0.9971 - learning_rate: 3.5407e-05
# Epoch 17/50
# 555/555 - 34s - 62ms/step - accuracy: 0.9864 - auc: 0.9987 - loss: 0.0396 - precision: 0.9896 - recall: 0.9860 - val_accuracy: 0.9978 - val_auc: 1.0000 - val_loss: 0.0075 - val_precision: 0.9994 - val_recall: 0.9966 - learning_rate: 3.5407e-05
# Epoch 18/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9864 - auc: 0.9986 - loss: 0.0400 - precision: 0.9894 - recall: 0.9863 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_loss: 0.0070 - val_precision: 0.9989 - val_recall: 0.9994 - learning_rate: 3.5407e-05
# Epoch 19/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9868 - auc: 0.9987 - loss: 0.0390 - precision: 0.9900 - recall: 0.9863 - val_accuracy: 0.9971 - val_auc: 1.0000 - val_loss: 0.0088 - val_precision: 0.9977 - val_recall: 0.9971 - learning_rate: 3.5407e-05
# Epoch 20/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9892 - auc: 0.9992 - loss: 0.0325 - precision: 0.9917 - recall: 0.9889 - val_accuracy: 0.9968 - val_auc: 1.0000 - val_loss: 0.0082 - val_precision: 0.9977 - val_recall: 0.9966 - learning_rate: 3.5407e-05
# Epoch 21/50
# 555/555 - 34s - 61ms/step - accuracy: 0.9889 - auc: 0.9993 - loss: 0.0314 - precision: 0.9916 - recall: 0.9885 - val_accuracy: 0.9974 - val_auc: 1.0000 - val_loss: 0.0070 - val_precision: 0.9989 - val_recall: 0.9966 - learning_rate: 3.5407e-05
# Epoch 22/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9883 - auc: 0.9990 - loss: 0.0348 - precision: 0.9904 - recall: 0.9887 - val_accuracy: 0.9974 - val_auc: 1.0000 - val_loss: 0.0072 - val_precision: 0.9977 - val_recall: 0.9977 - learning_rate: 3.5407e-05
# Epoch 23/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9893 - auc: 0.9992 - loss: 0.0308 - precision: 0.9915 - recall: 0.9893 - val_accuracy: 0.9965 - val_auc: 1.0000 - val_loss: 0.0095 - val_precision: 1.0000 - val_recall: 0.9937 - learning_rate: 3.5407e-05
# Epoch 24/50
# 555/555 - 34s - 61ms/step - accuracy: 0.9901 - auc: 0.9994 - loss: 0.0279 - precision: 0.9922 - recall: 0.9900 - val_accuracy: 0.9984 - val_auc: 1.0000 - val_loss: 0.0047 - val_precision: 0.9994 - val_recall: 0.9977 - learning_rate: 7.0815e-06
# Epoch 25/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9905 - auc: 0.9994 - loss: 0.0281 - precision: 0.9920 - recall: 0.9909 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_loss: 0.0043 - val_precision: 1.0000 - val_recall: 0.9977 - learning_rate: 7.0815e-06
# Epoch 26/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9905 - auc: 0.9994 - loss: 0.0272 - precision: 0.9932 - recall: 0.9897 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_loss: 0.0041 - val_precision: 0.9989 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 27/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9919 - auc: 0.9995 - loss: 0.0248 - precision: 0.9944 - recall: 0.9910 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0042 - val_precision: 1.0000 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 28/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9921 - auc: 0.9995 - loss: 0.0239 - precision: 0.9936 - recall: 0.9922 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_loss: 0.0038 - val_precision: 0.9994 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 29/50
# 555/555 - 35s - 62ms/step - accuracy: 0.9920 - auc: 0.9997 - loss: 0.0238 - precision: 0.9936 - recall: 0.9920 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0032 - val_precision: 1.0000 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 30/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9909 - auc: 0.9994 - loss: 0.0252 - precision: 0.9935 - recall: 0.9902 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0031 - val_precision: 1.0000 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 31/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9922 - auc: 0.9995 - loss: 0.0233 - precision: 0.9940 - recall: 0.9920 - val_accuracy: 0.9997 - val_auc: 1.0000 - val_loss: 0.0031 - val_precision: 1.0000 - val_recall: 0.9994 - learning_rate: 7.0815e-06
# Epoch 32/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9929 - auc: 0.9995 - loss: 0.0212 - precision: 0.9949 - recall: 0.9923 - val_accuracy: 0.9990 - val_auc: 1.0000 - val_loss: 0.0030 - val_precision: 1.0000 - val_recall: 0.9983 - learning_rate: 7.0815e-06
# Epoch 33/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9921 - auc: 0.9995 - loss: 0.0227 - precision: 0.9943 - recall: 0.9914 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0031 - val_precision: 1.0000 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 34/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9918 - auc: 0.9995 - loss: 0.0242 - precision: 0.9932 - recall: 0.9921 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0032 - val_precision: 1.0000 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 35/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9929 - auc: 0.9995 - loss: 0.0221 - precision: 0.9936 - recall: 0.9936 - val_accuracy: 0.9997 - val_auc: 1.0000 - val_loss: 0.0032 - val_precision: 1.0000 - val_recall: 0.9994 - learning_rate: 7.0815e-06
# Epoch 36/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9927 - auc: 0.9997 - loss: 0.0213 - precision: 0.9949 - recall: 0.9920 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0025 - val_precision: 0.9994 - val_recall: 0.9994 - learning_rate: 7.0815e-06
# Epoch 37/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9927 - auc: 0.9995 - loss: 0.0224 - precision: 0.9941 - recall: 0.9927 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0031 - val_precision: 1.0000 - val_recall: 0.9989 - learning_rate: 7.0815e-06
# Epoch 38/50
# 555/555 - 33s - 60ms/step - accuracy: 0.9925 - auc: 0.9996 - loss: 0.0215 - precision: 0.9938 - recall: 0.9926 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0026 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 7.0815e-06
# Epoch 39/50
# 555/555 - 34s - 61ms/step - accuracy: 0.9931 - auc: 0.9995 - loss: 0.0213 - precision: 0.9951 - recall: 0.9924 - val_accuracy: 0.9994 - val_auc: 1.0000 - val_loss: 0.0026 - val_precision: 1.0000 - val_recall: 0.9989 - learning_rate: 7.0815e-06
#
# Optimizing classification threshold...
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 29s 166ms/step
# Optimal threshold: 0.3892
#
# Final Evaluation:
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 15s 126ms/step
#
# ============================== Evaluation Results ==============================
# Accuracy: 1.0000
# AUC: 1.0000
# Precision: 1.0000
# Recall (Sensitivity): 1.0000
# Specificity: 1.0000
# F1 Score: 1.0000
# Confusion Matrix:
# [[1630    0]
#  [   0 2057]]
# ==============================================================================
#
#
# === Final Results Summary ===
#
# DenseNet121:
# AUC: 1.0000 | Accuracy: 1.0000
# Precision: 1.0000 | Recall: 1.0000
# F1: 1.0000 | Specificity: 1.0000
# Optimal Threshold: 0.3892
