# %%
# Imports
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet121, EfficientNetB3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold
import pickle
import collections
from sklearn.metrics import (
    accuracy_score, roc_auc_score, precision_score, recall_score,
    f1_score, confusion_matrix, roc_curve
)

# %%
# Use Mixed Precision (save VRAM)
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")
print("mixed precision enabled.")
# Out:
# mixed precision enabled.

# %%
# Load Preprocessed Data --- balanced checked
DATA_PATH = "/kaggle/input/preprocessed-mammo-splits"  
train = np.load(os.path.join(DATA_PATH, "train_data.npz"))
val = np.load(os.path.join(DATA_PATH, "val_data.npz"))
test = np.load(os.path.join(DATA_PATH, "test_data.npz"))

X_train, y_train = train["X"], train["y"]
X_val, y_val = val["X"], val["y"]
X_test, y_test = test["X"], test["y"]

# %%
# Compute Class Weights
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))
print("Class Weights:", class_weight_dict)
# Out:
# Class Weights: {0: 1.1308917197452228, 1: 0.8962645128722867}

# %%
# Expand dims because TF expects (H, W, 1) from (H, W)
X_train = X_train[..., np.newaxis].astype("float32")
X_val = X_val[..., np.newaxis].astype("float32")
X_test = X_test[..., np.newaxis].astype("float32")

# %%
# Enhanced data augmentation
def convert_to_rgb(image, label):
    image_rgb = tf.image.grayscale_to_rgb(image)  
    image_rgb = tf.squeeze(image_rgb) 
    return image_rgb, label

# %%
def augment(image, label):
    # Random rotation (0-15 degrees)
    angle = tf.random.uniform([], -0.26, 0.26)  # ~15 degrees in radians
    image = tf.image.rot90(image, k=tf.cast(angle * 2 / 3.14159, tf.int32))
    
    # Random flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    # Random brightness/contrast adjustments
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    
    # Random zoom (crop and resize)
    zoom_factor = tf.random.uniform([], 0.8, 1.0, dtype=tf.float32)
    h, w = tf.shape(image)[0], tf.shape(image)[1]
    crop_size_h = tf.cast(tf.cast(h, tf.float32) * zoom_factor, tf.int32)
    crop_size_w = tf.cast(tf.cast(w, tf.float32) * zoom_factor, tf.int32)
    
    # Ensure crop dimensions don't exceed image dimensions
    crop_size_h = tf.minimum(crop_size_h, h)
    crop_size_w = tf.minimum(crop_size_w, w)
    
    image = tf.image.random_crop(image, size=[crop_size_h, crop_size_w, 3])
    image = tf.image.resize(image, [224, 224])
    
    return image, label

# %%
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

# Create datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Apply preprocessing and augmentation
train_ds = (
    train_ds.shuffle(1024)
    .map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .map(augment, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

val_ds = (
    val_ds.map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = (
    test_ds.map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
# Out:
# I0000 00:00:1745486477.846563      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
def build_improved_model(base_model_fn, name="model", lr=1e-4):
    base_model = base_model_fn(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
    # Initially freeze the base model
    base_model.trainable = False
    
    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    
    # Enhanced architecture with more layers
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    outputs = Dense(1, activation='sigmoid', dtype='float32')(x)
    
    model = Model(inputs, outputs, name=name)

    # Use simple float learning rate instead of schedule
    model.compile(
        optimizer=Adam(learning_rate=lr),  # Simple float learning rate
        loss='binary_crossentropy',
        metrics=[
            'accuracy', 
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model, base_model

# %%
# unfreeze_model function --- finetuning
def unfreeze_model(model, base_model, lr=1e-5):
    # Unfreeze the base model
    base_model.trainable = True
    
    # Freeze earlier layers, unfreeze later layers (fine-tuning)
    for layer in base_model.layers[:-30]:  # Keep the first layers frozen
        layer.trainable = False
    
    # Use simple float learning rate
    model.compile(
        optimizer=Adam(learning_rate=lr),  # Simple float learning rate
        loss='binary_crossentropy',
        metrics=[
            'accuracy', 
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model

# %%
# Function to find the optimal threshold using the validation set
def find_optimal_threshold(model, val_ds):
    # Get predictions
    val_pred = model.predict(val_ds)
    
    # Get true labels
    val_true = np.concatenate([y for x, y in val_ds], axis=0)
    
    # Calculate ROC curve and find optimal threshold
    fpr, tpr, thresholds = roc_curve(val_true, val_pred)
    j_scores = tpr - fpr
    best_idx = np.argmax(j_scores)
    best_threshold = thresholds[best_idx]
    
    print(f"Optimal threshold: {best_threshold:.4f} (Youden's J = {j_scores[best_idx]:.4f})")
    print(f"At threshold {best_threshold:.4f}: TPR={tpr[best_idx]:.4f}, FPR={fpr[best_idx]:.4f}")
    
    return best_threshold

# %%
def evaluate_with_threshold(model, ds, threshold=0.5):
    # Get predictions
    pred = model.predict(ds)
    
    # Get true labels
    true = np.concatenate([y for x, y in ds], axis=0)
    
    # Apply threshold
    pred_binary = (pred > threshold).astype(int)
    
    # Calculate metrics
    acc = accuracy_score(true, pred_binary)
    auc = roc_auc_score(true, pred)
    precision = precision_score(true, pred_binary)
    recall = recall_score(true, pred_binary)
    f1 = f1_score(true, pred_binary)
    cm = confusion_matrix(true, pred_binary)
    
    # Calculate specificity
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)
    
    print(f"Accuracy: {acc:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Confusion Matrix:\n{cm}")
    
    return {
        'accuracy': acc,
        'auc': auc,
        'precision': precision,
        'recall': recall,
        'specificity': specificity,
        'f1': f1,
        'confusion_matrix': cm,
        'predictions': pred,
        'threshold': threshold
    }

# %%
# Prepare Callbacks
os.makedirs("/kaggle/working/models", exist_ok=True)

def get_callbacks(name):
    return [
        # Stop training when validation loss doesn't improve for 15 epochs
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            verbose=1
        ),
        # Save the best model during training
        ModelCheckpoint(
            f"/kaggle/working/models/{name}.keras",
            save_best_only=True,
            monitor='val_auc',
            mode='max',
            verbose=1
        ),
        # Reduce learning rate when validation loss plateaus
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]

# %%
models_to_train = {
    # "VGG16": VGG16
    # "ResNet50": ResNet50
    "DenseNet121": DenseNet121
    # "EfficientNetB3": EfficientNetB3  
}

# %%
# Store training histories and model results
history_dict = {}
model_results = {}
all_trained_models = {}

# %%
for name, model_fn in models_to_train.items():
    print(f"\n{'='*50}")
    print(f"Training {name}...")
    print(f"{'='*50}")
    
    # Build model
    model, base_model = build_improved_model(model_fn, name=name)
    
    print(f"Initial training with frozen base layers...")
    
    # Phase 1: Train with frozen base model
    history1 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,  # Initial training epochs
        class_weight=class_weight_dict,
        callbacks=get_callbacks(f"{name}_phase1"),
        verbose=2
    )
    
    # Phase 2: Fine-tuning with unfrozen layers
    print(f"\nFine-tuning with unfrozen layers...")
    model = unfreeze_model(model, base_model, lr=1e-5)
    history2 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,  # Fine-tuning epochs
        class_weight=class_weight_dict,
        callbacks=get_callbacks(f"{name}_phase2"),
        verbose=2
    )
    
    # Find optimal threshold
    print("\nFinding optimal threshold...")
    optimal_threshold = find_optimal_threshold(model, val_ds)
    
    # Evaluate model on test set with optimal threshold
    print("\nEvaluating on test set...")
    test_results = evaluate_with_threshold(model, test_ds, threshold=optimal_threshold)
    model_results[name] = test_results
    
    # Save model
    model.save(f"{name}_trained_model.h5")
    print(f"Saved model: {name}_trained_model.h5")
    
    # Save training history
    combined_history = {
        'phase1': history1.history,
        'phase2': history2.history
    }
    history_dict[name] = combined_history
    with open(f"{name}_history.pkl", "wb") as f:
        pickle.dump(combined_history, f)
    print(f"Saved training history: {name}_history.pkl")
    
    # Store model for ensemble
    all_trained_models[name] = model
# Out:
# ==================================================
# Training DenseNet121...
# ==================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Initial training with frozen base layers...
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745486626.509503      95 service.cc:148] XLA service 0x7e87a8003220 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745486626.510138      95 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745486629.724857      95 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745486643.278648      95 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_auc improved from -inf to 0.88923, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 115s - 206ms/step - accuracy: 0.6679 - auc: 0.7290 - loss: 0.6524 - precision: 0.7271 - recall: 0.6480 - val_accuracy: 0.7856 - val_auc: 0.8892 - val_loss: 0.4375 - val_precision: 0.8587 - val_recall: 0.7368 - learning_rate: 1.0000e-04
# Epoch 2/30
#
# Epoch 2: val_auc improved from 0.88923 to 0.92608, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 58ms/step - accuracy: 0.7641 - auc: 0.8491 - loss: 0.4872 - precision: 0.8081 - recall: 0.7568 - val_accuracy: 0.8408 - val_auc: 0.9261 - val_loss: 0.3593 - val_precision: 0.8935 - val_recall: 0.8112 - learning_rate: 1.0000e-04
# Epoch 3/30
#
# Epoch 3: val_auc improved from 0.92608 to 0.94576, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.7973 - auc: 0.8855 - loss: 0.4262 - precision: 0.8353 - recall: 0.7930 - val_accuracy: 0.8647 - val_auc: 0.9458 - val_loss: 0.3034 - val_precision: 0.8955 - val_recall: 0.8576 - learning_rate: 1.0000e-04
# Epoch 4/30
#
# Epoch 4: val_auc improved from 0.94576 to 0.95138, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 57ms/step - accuracy: 0.8192 - auc: 0.9055 - loss: 0.3889 - precision: 0.8560 - recall: 0.8126 - val_accuracy: 0.8673 - val_auc: 0.9514 - val_loss: 0.2795 - val_precision: 0.8797 - val_recall: 0.8827 - learning_rate: 1.0000e-04
# Epoch 5/30
#
# Epoch 5: val_auc improved from 0.95138 to 0.95991, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.8333 - auc: 0.9189 - loss: 0.3613 - precision: 0.8668 - recall: 0.8285 - val_accuracy: 0.8839 - val_auc: 0.9599 - val_loss: 0.2577 - val_precision: 0.9014 - val_recall: 0.8890 - learning_rate: 1.0000e-04
# Epoch 6/30
#
# Epoch 6: val_auc improved from 0.95991 to 0.96685, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 57ms/step - accuracy: 0.8487 - auc: 0.9307 - loss: 0.3345 - precision: 0.8776 - recall: 0.8468 - val_accuracy: 0.8947 - val_auc: 0.9668 - val_loss: 0.2393 - val_precision: 0.9230 - val_recall: 0.8850 - learning_rate: 1.0000e-04
# Epoch 7/30
#
# Epoch 7: val_auc improved from 0.96685 to 0.96772, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.8480 - auc: 0.9343 - loss: 0.3254 - precision: 0.8778 - recall: 0.8451 - val_accuracy: 0.8947 - val_auc: 0.9677 - val_loss: 0.2423 - val_precision: 0.9366 - val_recall: 0.8701 - learning_rate: 1.0000e-04
# Epoch 8/30
#
# Epoch 8: val_auc improved from 0.96772 to 0.97080, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 57ms/step - accuracy: 0.8638 - auc: 0.9427 - loss: 0.3047 - precision: 0.8924 - recall: 0.8596 - val_accuracy: 0.9011 - val_auc: 0.9708 - val_loss: 0.2235 - val_precision: 0.9275 - val_recall: 0.8924 - learning_rate: 1.0000e-04
# Epoch 9/30
#
# Epoch 9: val_auc improved from 0.97080 to 0.97583, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.8696 - auc: 0.9464 - loss: 0.2946 - precision: 0.8957 - recall: 0.8672 - val_accuracy: 0.9059 - val_auc: 0.9758 - val_loss: 0.2167 - val_precision: 0.9566 - val_recall: 0.8707 - learning_rate: 1.0000e-04
# Epoch 10/30
#
# Epoch 10: val_auc improved from 0.97583 to 0.97768, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 58ms/step - accuracy: 0.8741 - auc: 0.9494 - loss: 0.2875 - precision: 0.9000 - recall: 0.8711 - val_accuracy: 0.9161 - val_auc: 0.9777 - val_loss: 0.1982 - val_precision: 0.9386 - val_recall: 0.9090 - learning_rate: 1.0000e-04
# Epoch 11/30
#
# Epoch 11: val_auc improved from 0.97768 to 0.97856, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 57ms/step - accuracy: 0.8776 - auc: 0.9526 - loss: 0.2776 - precision: 0.9028 - recall: 0.8748 - val_accuracy: 0.9126 - val_auc: 0.9786 - val_loss: 0.1957 - val_precision: 0.9403 - val_recall: 0.9005 - learning_rate: 1.0000e-04
# Epoch 12/30
#
# Epoch 12: val_auc improved from 0.97856 to 0.98126, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 41s - 74ms/step - accuracy: 0.8844 - auc: 0.9575 - loss: 0.2632 - precision: 0.9093 - recall: 0.8806 - val_accuracy: 0.9218 - val_auc: 0.9813 - val_loss: 0.1906 - val_precision: 0.9580 - val_recall: 0.8993 - learning_rate: 1.0000e-04
# Epoch 13/30
#
# Epoch 13: val_auc improved from 0.98126 to 0.98314, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.8910 - auc: 0.9620 - loss: 0.2493 - precision: 0.9148 - recall: 0.8873 - val_accuracy: 0.9225 - val_auc: 0.9831 - val_loss: 0.1798 - val_precision: 0.9558 - val_recall: 0.9027 - learning_rate: 1.0000e-04
# Epoch 14/30
#
# Epoch 14: val_auc improved from 0.98314 to 0.98353, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.8949 - auc: 0.9628 - loss: 0.2467 - precision: 0.9186 - recall: 0.8906 - val_accuracy: 0.9298 - val_auc: 0.9835 - val_loss: 0.1702 - val_precision: 0.9452 - val_recall: 0.9279 - learning_rate: 1.0000e-04
# Epoch 15/30
#
# Epoch 15: val_auc improved from 0.98353 to 0.98531, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.8987 - auc: 0.9657 - loss: 0.2368 - precision: 0.9186 - recall: 0.8980 - val_accuracy: 0.9365 - val_auc: 0.9853 - val_loss: 0.1600 - val_precision: 0.9485 - val_recall: 0.9371 - learning_rate: 1.0000e-04
# Epoch 16/30
#
# Epoch 16: val_auc did not improve from 0.98531
# 555/555 - 30s - 55ms/step - accuracy: 0.8989 - auc: 0.9652 - loss: 0.2387 - precision: 0.9178 - recall: 0.8993 - val_accuracy: 0.9346 - val_auc: 0.9848 - val_loss: 0.1636 - val_precision: 0.9584 - val_recall: 0.9228 - learning_rate: 1.0000e-04
# Epoch 17/30
#
# Epoch 17: val_auc improved from 0.98531 to 0.98701, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 57ms/step - accuracy: 0.9044 - auc: 0.9692 - loss: 0.2248 - precision: 0.9263 - recall: 0.9003 - val_accuracy: 0.9400 - val_auc: 0.9870 - val_loss: 0.1519 - val_precision: 0.9567 - val_recall: 0.9348 - learning_rate: 1.0000e-04
# Epoch 18/30
#
# Epoch 18: val_auc did not improve from 0.98701
# 555/555 - 40s - 72ms/step - accuracy: 0.9064 - auc: 0.9697 - loss: 0.2231 - precision: 0.9263 - recall: 0.9041 - val_accuracy: 0.9416 - val_auc: 0.9864 - val_loss: 0.1504 - val_precision: 0.9495 - val_recall: 0.9457 - learning_rate: 1.0000e-04
# Epoch 19/30
#
# Epoch 19: val_auc improved from 0.98701 to 0.98837, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.9081 - auc: 0.9717 - loss: 0.2157 - precision: 0.9256 - recall: 0.9082 - val_accuracy: 0.9432 - val_auc: 0.9884 - val_loss: 0.1439 - val_precision: 0.9612 - val_recall: 0.9359 - learning_rate: 1.0000e-04
# Epoch 20/30
#
# Epoch 20: val_auc did not improve from 0.98837
# 555/555 - 30s - 55ms/step - accuracy: 0.9112 - auc: 0.9736 - loss: 0.2080 - precision: 0.9306 - recall: 0.9086 - val_accuracy: 0.9400 - val_auc: 0.9883 - val_loss: 0.1439 - val_precision: 0.9604 - val_recall: 0.9308 - learning_rate: 1.0000e-04
# Epoch 21/30
#
# Epoch 21: val_auc improved from 0.98837 to 0.99023, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.9150 - auc: 0.9750 - loss: 0.2026 - precision: 0.9345 - recall: 0.9116 - val_accuracy: 0.9480 - val_auc: 0.9902 - val_loss: 0.1349 - val_precision: 0.9681 - val_recall: 0.9376 - learning_rate: 1.0000e-04
# Epoch 22/30
#
# Epoch 22: val_auc did not improve from 0.99023
# 555/555 - 30s - 55ms/step - accuracy: 0.9170 - auc: 0.9744 - loss: 0.2045 - precision: 0.9352 - recall: 0.9147 - val_accuracy: 0.9426 - val_auc: 0.9894 - val_loss: 0.1351 - val_precision: 0.9601 - val_recall: 0.9359 - learning_rate: 1.0000e-04
# Epoch 23/30
#
# Epoch 23: val_auc did not improve from 0.99023
# 555/555 - 30s - 55ms/step - accuracy: 0.9173 - auc: 0.9761 - loss: 0.1981 - precision: 0.9342 - recall: 0.9162 - val_accuracy: 0.9461 - val_auc: 0.9874 - val_loss: 0.1417 - val_precision: 0.9524 - val_recall: 0.9508 - learning_rate: 1.0000e-04
# Epoch 24/30
#
# Epoch 24: val_auc did not improve from 0.99023
# 555/555 - 31s - 55ms/step - accuracy: 0.9208 - auc: 0.9763 - loss: 0.1966 - precision: 0.9380 - recall: 0.9188 - val_accuracy: 0.9442 - val_auc: 0.9891 - val_loss: 0.1339 - val_precision: 0.9396 - val_recall: 0.9617 - learning_rate: 1.0000e-04
# Epoch 25/30
#
# Epoch 25: val_auc improved from 0.99023 to 0.99073, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.9214 - auc: 0.9776 - loss: 0.1914 - precision: 0.9359 - recall: 0.9223 - val_accuracy: 0.9505 - val_auc: 0.9907 - val_loss: 0.1239 - val_precision: 0.9533 - val_recall: 0.9582 - learning_rate: 1.0000e-04
# Epoch 26/30
#
# Epoch 26: val_auc improved from 0.99073 to 0.99154, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.9225 - auc: 0.9774 - loss: 0.1923 - precision: 0.9390 - recall: 0.9209 - val_accuracy: 0.9531 - val_auc: 0.9915 - val_loss: 0.1182 - val_precision: 0.9582 - val_recall: 0.9577 - learning_rate: 1.0000e-04
# Epoch 27/30
#
# Epoch 27: val_auc improved from 0.99154 to 0.99174, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 31s - 57ms/step - accuracy: 0.9210 - auc: 0.9789 - loss: 0.1860 - precision: 0.9367 - recall: 0.9205 - val_accuracy: 0.9550 - val_auc: 0.9917 - val_loss: 0.1166 - val_precision: 0.9589 - val_recall: 0.9605 - learning_rate: 1.0000e-04
# Epoch 28/30
#
# Epoch 28: val_auc improved from 0.99174 to 0.99276, saving model to /kaggle/working/models/DenseNet121_phase1.keras
# 555/555 - 32s - 58ms/step - accuracy: 0.9297 - auc: 0.9815 - loss: 0.1738 - precision: 0.9434 - recall: 0.9296 - val_accuracy: 0.9582 - val_auc: 0.9928 - val_loss: 0.1123 - val_precision: 0.9714 - val_recall: 0.9531 - learning_rate: 1.0000e-04
# Epoch 29/30
#
# Epoch 29: val_auc did not improve from 0.99276
# 555/555 - 31s - 55ms/step - accuracy: 0.9258 - auc: 0.9797 - loss: 0.1821 - precision: 0.9416 - recall: 0.9244 - val_accuracy: 0.9572 - val_auc: 0.9926 - val_loss: 0.1106 - val_precision: 0.9585 - val_recall: 0.9651 - learning_rate: 1.0000e-04
# Epoch 30/30
#
# Epoch 30: val_auc did not improve from 0.99276
# 555/555 - 30s - 55ms/step - accuracy: 0.9294 - auc: 0.9817 - loss: 0.1726 - precision: 0.9453 - recall: 0.9271 - val_accuracy: 0.9486 - val_auc: 0.9919 - val_loss: 0.1154 - val_precision: 0.9568 - val_recall: 0.9508 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 29.
#
# Fine-tuning with unfrozen layers...
# Epoch 1/30
#
# Epoch 1: val_auc improved from -inf to 0.98706, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 113s - 203ms/step - accuracy: 0.8759 - auc: 0.9498 - loss: 0.2958 - precision: 0.8897 - recall: 0.8875 - val_accuracy: 0.9435 - val_auc: 0.9871 - val_loss: 0.1448 - val_precision: 0.9559 - val_recall: 0.9422 - learning_rate: 1.0000e-05
# Epoch 2/30
#
# Epoch 2: val_auc improved from 0.98706 to 0.99005, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9036 - auc: 0.9666 - loss: 0.2345 - precision: 0.9207 - recall: 0.9052 - val_accuracy: 0.9515 - val_auc: 0.9901 - val_loss: 0.1268 - val_precision: 0.9597 - val_recall: 0.9531 - learning_rate: 1.0000e-05
# Epoch 3/30
#
# Epoch 3: val_auc improved from 0.99005 to 0.99200, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9139 - auc: 0.9730 - loss: 0.2101 - precision: 0.9302 - recall: 0.9142 - val_accuracy: 0.9521 - val_auc: 0.9920 - val_loss: 0.1183 - val_precision: 0.9683 - val_recall: 0.9451 - learning_rate: 1.0000e-05
# Epoch 4/30
#
# Epoch 4: val_auc improved from 0.99200 to 0.99325, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9189 - auc: 0.9766 - loss: 0.1950 - precision: 0.9373 - recall: 0.9159 - val_accuracy: 0.9550 - val_auc: 0.9933 - val_loss: 0.1078 - val_precision: 0.9636 - val_recall: 0.9554 - learning_rate: 1.0000e-05
# Epoch 5/30
#
# Epoch 5: val_auc improved from 0.99325 to 0.99426, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9186 - auc: 0.9756 - loss: 0.1999 - precision: 0.9367 - recall: 0.9160 - val_accuracy: 0.9588 - val_auc: 0.9943 - val_loss: 0.1013 - val_precision: 0.9698 - val_recall: 0.9559 - learning_rate: 1.0000e-05
# Epoch 6/30
#
# Epoch 6: val_auc improved from 0.99426 to 0.99477, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9271 - auc: 0.9800 - loss: 0.1807 - precision: 0.9428 - recall: 0.9255 - val_accuracy: 0.9627 - val_auc: 0.9948 - val_loss: 0.0957 - val_precision: 0.9728 - val_recall: 0.9600 - learning_rate: 1.0000e-05
# Epoch 7/30
#
# Epoch 7: val_auc improved from 0.99477 to 0.99575, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 60ms/step - accuracy: 0.9308 - auc: 0.9824 - loss: 0.1693 - precision: 0.9466 - recall: 0.9284 - val_accuracy: 0.9652 - val_auc: 0.9957 - val_loss: 0.0887 - val_precision: 0.9734 - val_recall: 0.9640 - learning_rate: 1.0000e-05
# Epoch 8/30
#
# Epoch 8: val_auc improved from 0.99575 to 0.99612, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9332 - auc: 0.9838 - loss: 0.1624 - precision: 0.9474 - recall: 0.9320 - val_accuracy: 0.9668 - val_auc: 0.9961 - val_loss: 0.0846 - val_precision: 0.9746 - val_recall: 0.9657 - learning_rate: 1.0000e-05
# Epoch 9/30
#
# Epoch 9: val_auc improved from 0.99612 to 0.99657, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 61ms/step - accuracy: 0.9382 - auc: 0.9850 - loss: 0.1563 - precision: 0.9547 - recall: 0.9335 - val_accuracy: 0.9681 - val_auc: 0.9966 - val_loss: 0.0793 - val_precision: 0.9736 - val_recall: 0.9691 - learning_rate: 1.0000e-05
# Epoch 10/30
#
# Epoch 10: val_auc improved from 0.99657 to 0.99714, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 40s - 73ms/step - accuracy: 0.9397 - auc: 0.9856 - loss: 0.1519 - precision: 0.9522 - recall: 0.9391 - val_accuracy: 0.9694 - val_auc: 0.9971 - val_loss: 0.0762 - val_precision: 0.9808 - val_recall: 0.9640 - learning_rate: 1.0000e-05
# Epoch 11/30
#
# Epoch 11: val_auc improved from 0.99714 to 0.99748, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 61ms/step - accuracy: 0.9417 - auc: 0.9865 - loss: 0.1476 - precision: 0.9541 - recall: 0.9407 - val_accuracy: 0.9735 - val_auc: 0.9975 - val_loss: 0.0703 - val_precision: 0.9793 - val_recall: 0.9731 - learning_rate: 1.0000e-05
# Epoch 12/30
#
# Epoch 12: val_auc improved from 0.99748 to 0.99762, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 60ms/step - accuracy: 0.9431 - auc: 0.9872 - loss: 0.1429 - precision: 0.9560 - recall: 0.9412 - val_accuracy: 0.9726 - val_auc: 0.9976 - val_loss: 0.0682 - val_precision: 0.9781 - val_recall: 0.9725 - learning_rate: 1.0000e-05
# Epoch 13/30
#
# Epoch 13: val_auc improved from 0.99762 to 0.99793, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 61ms/step - accuracy: 0.9462 - auc: 0.9885 - loss: 0.1360 - precision: 0.9583 - recall: 0.9446 - val_accuracy: 0.9751 - val_auc: 0.9979 - val_loss: 0.0655 - val_precision: 0.9832 - val_recall: 0.9720 - learning_rate: 1.0000e-05
# Epoch 14/30
#
# Epoch 14: val_auc improved from 0.99793 to 0.99809, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 61ms/step - accuracy: 0.9453 - auc: 0.9882 - loss: 0.1383 - precision: 0.9580 - recall: 0.9434 - val_accuracy: 0.9777 - val_auc: 0.9981 - val_loss: 0.0617 - val_precision: 0.9822 - val_recall: 0.9777 - learning_rate: 1.0000e-05
# Epoch 15/30
#
# Epoch 15: val_auc improved from 0.99809 to 0.99832, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 61ms/step - accuracy: 0.9520 - auc: 0.9911 - loss: 0.1221 - precision: 0.9659 - recall: 0.9474 - val_accuracy: 0.9805 - val_auc: 0.9983 - val_loss: 0.0577 - val_precision: 0.9823 - val_recall: 0.9828 - learning_rate: 1.0000e-05
# Epoch 16/30
#
# Epoch 16: val_auc improved from 0.99832 to 0.99854, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9526 - auc: 0.9909 - loss: 0.1212 - precision: 0.9634 - recall: 0.9511 - val_accuracy: 0.9837 - val_auc: 0.9985 - val_loss: 0.0536 - val_precision: 0.9857 - val_recall: 0.9851 - learning_rate: 1.0000e-05
# Epoch 17/30
#
# Epoch 17: val_auc improved from 0.99854 to 0.99875, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9555 - auc: 0.9915 - loss: 0.1167 - precision: 0.9671 - recall: 0.9527 - val_accuracy: 0.9840 - val_auc: 0.9987 - val_loss: 0.0522 - val_precision: 0.9885 - val_recall: 0.9828 - learning_rate: 1.0000e-05
# Epoch 18/30
#
# Epoch 18: val_auc improved from 0.99875 to 0.99886, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 61ms/step - accuracy: 0.9565 - auc: 0.9928 - loss: 0.1086 - precision: 0.9664 - recall: 0.9552 - val_accuracy: 0.9850 - val_auc: 0.9989 - val_loss: 0.0483 - val_precision: 0.9885 - val_recall: 0.9846 - learning_rate: 1.0000e-05
# Epoch 19/30
#
# Epoch 19: val_auc did not improve from 0.99886
# 555/555 - 32s - 58ms/step - accuracy: 0.9582 - auc: 0.9921 - loss: 0.1122 - precision: 0.9700 - recall: 0.9545 - val_accuracy: 0.9863 - val_auc: 0.9988 - val_loss: 0.0485 - val_precision: 0.9874 - val_recall: 0.9880 - learning_rate: 1.0000e-05
# Epoch 20/30
#
# Epoch 20: val_auc improved from 0.99886 to 0.99905, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9614 - auc: 0.9932 - loss: 0.1048 - precision: 0.9696 - recall: 0.9609 - val_accuracy: 0.9866 - val_auc: 0.9991 - val_loss: 0.0451 - val_precision: 0.9902 - val_recall: 0.9857 - learning_rate: 1.0000e-05
# Epoch 21/30
#
# Epoch 21: val_auc improved from 0.99905 to 0.99919, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9616 - auc: 0.9936 - loss: 0.1010 - precision: 0.9723 - recall: 0.9584 - val_accuracy: 0.9866 - val_auc: 0.9992 - val_loss: 0.0424 - val_precision: 0.9885 - val_recall: 0.9874 - learning_rate: 1.0000e-05
# Epoch 22/30
#
# Epoch 22: val_auc improved from 0.99919 to 0.99932, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9601 - auc: 0.9931 - loss: 0.1057 - precision: 0.9694 - recall: 0.9588 - val_accuracy: 0.9885 - val_auc: 0.9993 - val_loss: 0.0394 - val_precision: 0.9903 - val_recall: 0.9891 - learning_rate: 1.0000e-05
# Epoch 23/30
#
# Epoch 23: val_auc improved from 0.99932 to 0.99940, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9642 - auc: 0.9947 - loss: 0.0932 - precision: 0.9727 - recall: 0.9629 - val_accuracy: 0.9888 - val_auc: 0.9994 - val_loss: 0.0383 - val_precision: 0.9908 - val_recall: 0.9891 - learning_rate: 1.0000e-05
# Epoch 24/30
#
# Epoch 24: val_auc improved from 0.99940 to 0.99941, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 34s - 61ms/step - accuracy: 0.9619 - auc: 0.9934 - loss: 0.1013 - precision: 0.9695 - recall: 0.9619 - val_accuracy: 0.9892 - val_auc: 0.9994 - val_loss: 0.0374 - val_precision: 0.9914 - val_recall: 0.9891 - learning_rate: 1.0000e-05
# Epoch 25/30
#
# Epoch 25: val_auc improved from 0.99941 to 0.99946, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9631 - auc: 0.9934 - loss: 0.1014 - precision: 0.9723 - recall: 0.9612 - val_accuracy: 0.9898 - val_auc: 0.9995 - val_loss: 0.0347 - val_precision: 0.9897 - val_recall: 0.9920 - learning_rate: 1.0000e-05
# Epoch 26/30
#
# Epoch 26: val_auc did not improve from 0.99946
# 555/555 - 32s - 58ms/step - accuracy: 0.9659 - auc: 0.9948 - loss: 0.0907 - precision: 0.9740 - recall: 0.9647 - val_accuracy: 0.9914 - val_auc: 0.9994 - val_loss: 0.0340 - val_precision: 0.9931 - val_recall: 0.9914 - learning_rate: 1.0000e-05
# Epoch 27/30
#
# Epoch 27: val_auc improved from 0.99946 to 0.99956, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9669 - auc: 0.9953 - loss: 0.0868 - precision: 0.9739 - recall: 0.9666 - val_accuracy: 0.9895 - val_auc: 0.9996 - val_loss: 0.0321 - val_precision: 0.9908 - val_recall: 0.9903 - learning_rate: 1.0000e-05
# Epoch 28/30
#
# Epoch 28: val_auc improved from 0.99956 to 0.99961, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9698 - auc: 0.9957 - loss: 0.0827 - precision: 0.9772 - recall: 0.9684 - val_accuracy: 0.9920 - val_auc: 0.9996 - val_loss: 0.0297 - val_precision: 0.9926 - val_recall: 0.9931 - learning_rate: 1.0000e-05
# Epoch 29/30
#
# Epoch 29: val_auc improved from 0.99961 to 0.99969, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 59ms/step - accuracy: 0.9687 - auc: 0.9956 - loss: 0.0831 - precision: 0.9759 - recall: 0.9679 - val_accuracy: 0.9923 - val_auc: 0.9997 - val_loss: 0.0266 - val_precision: 0.9926 - val_recall: 0.9937 - learning_rate: 1.0000e-05
# Epoch 30/30
#
# Epoch 30: val_auc improved from 0.99969 to 0.99976, saving model to /kaggle/working/models/DenseNet121_phase2.keras
# 555/555 - 33s - 60ms/step - accuracy: 0.9705 - auc: 0.9954 - loss: 0.0839 - precision: 0.9775 - recall: 0.9694 - val_accuracy: 0.9933 - val_auc: 0.9998 - val_loss: 0.0248 - val_precision: 0.9943 - val_recall: 0.9937 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 30.
#
# Finding optimal threshold...
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 28s 162ms/step
# Optimal threshold: 0.5516 (Youden's J = 0.9879)
# At threshold 0.5516: TPR=0.9937, FPR=0.0058
#
# Evaluating on test set...
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 15s 125ms/step
# Accuracy: 0.9924
# AUC: 0.9997
# Precision: 0.9951
# Recall (Sensitivity): 0.9912
# Specificity: 0.9939
# F1 Score: 0.9932
# Confusion Matrix:
# [[1620   10]
#  [  18 2039]]
# Saved model: DenseNet121_trained_model.h5
# Saved training history: DenseNet121_history.pkl
