# %%
# Imports
import numpy as np
import os
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet121, EfficientNetB3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold
import pickle
import collections
from sklearn.metrics import (
    accuracy_score, roc_auc_score, precision_score, recall_score,
    f1_score, confusion_matrix, roc_curve
)

# %%
# Use Mixed Precision (save VRAM)
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy("mixed_float16")
print("mixed precision enabled.")
# Out:
# mixed precision enabled.

# %%
# Load Preprocessed Data --- balanced checked
DATA_PATH = "/kaggle/input/preprocessed-mammo-splits"  
train = np.load(os.path.join(DATA_PATH, "train_data.npz"))
val = np.load(os.path.join(DATA_PATH, "val_data.npz"))
test = np.load(os.path.join(DATA_PATH, "test_data.npz"))

X_train, y_train = train["X"], train["y"]
X_val, y_val = val["X"], val["y"]
X_test, y_test = test["X"], test["y"]

# %%
# Compute Class Weights
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))
print("Class Weights:", class_weight_dict)
# Out:
# Class Weights: {0: 1.1308917197452228, 1: 0.8962645128722867}

# %%
# Expand dims because TF expects (H, W, 1) from (H, W)
X_train = X_train[..., np.newaxis].astype("float32")
X_val = X_val[..., np.newaxis].astype("float32")
X_test = X_test[..., np.newaxis].astype("float32")

# %%
# Print data shapes
print(f"Training data shape: {X_train.shape}, Labels: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}, Labels: {y_val.shape}")
print(f"Test data shape: {X_test.shape}, Labels: {y_test.shape}")
# Out:
# Training data shape: (17755, 224, 224, 1, 1), Labels: (17755,)
# Validation data shape: (3134, 224, 224, 1, 1), Labels: (3134,)
# Test data shape: (3687, 224, 224, 1, 1), Labels: (3687,)

# %%
# Enhanced data augmentation
def convert_to_rgb(image, label):
    image_rgb = tf.image.grayscale_to_rgb(image)  
    image_rgb = tf.squeeze(image_rgb) 
    return image_rgb, label

# %%
def augment(image, label):
    # Random rotation (0-15 degrees)
    angle = tf.random.uniform([], -0.26, 0.26)  # ~15 degrees in radians
    image = tf.image.rot90(image, k=tf.cast(angle * 2 / 3.14159, tf.int32))
    
    # Random flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    # Random brightness/contrast adjustments
    image = tf.image.random_brightness(image, 0.2)
    image = tf.image.random_contrast(image, 0.8, 1.2)
    
    # Random zoom (crop and resize)
    zoom_factor = tf.random.uniform([], 0.8, 1.0, dtype=tf.float32)
    h, w = tf.shape(image)[0], tf.shape(image)[1]
    crop_size_h = tf.cast(tf.cast(h, tf.float32) * zoom_factor, tf.int32)
    crop_size_w = tf.cast(tf.cast(w, tf.float32) * zoom_factor, tf.int32)
    
    # Ensure crop dimensions don't exceed image dimensions
    crop_size_h = tf.minimum(crop_size_h, h)
    crop_size_w = tf.minimum(crop_size_w, w)
    
    image = tf.image.random_crop(image, size=[crop_size_h, crop_size_w, 3])
    image = tf.image.resize(image, [224, 224])
    
    return image, label

# %%
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE

# Create datasets
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))

# Apply preprocessing and augmentation
train_ds = (
    train_ds.shuffle(1024)
    .map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .map(augment, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

val_ds = (
    val_ds.map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)

test_ds = (
    test_ds.map(convert_to_rgb, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .prefetch(AUTOTUNE)
)
# Out:
# I0000 00:00:1745410578.000368      31 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
def build_improved_model(base_model_fn, name="model", lr=1e-4):
    base_model = base_model_fn(include_top=False, weights='imagenet', input_shape=(224, 224, 3))
    # Initially freeze the base model
    base_model.trainable = False
    
    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    
    # Enhanced architecture with more layers
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    
    outputs = Dense(1, activation='sigmoid', dtype='float32')(x)
    
    model = Model(inputs, outputs, name=name)
    
    # Use simple float learning rate instead of schedule
    model.compile(
        optimizer=Adam(learning_rate=lr),  # Simple float learning rate
        loss='binary_crossentropy',
        metrics=[
            'accuracy', 
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model, base_model

# %%
# unfreeze_model function --- finetuning
def unfreeze_model(model, base_model, lr=1e-5):
    # Unfreeze the base model
    base_model.trainable = True
    
    # Freeze earlier layers, unfreeze later layers (fine-tuning)
    for layer in base_model.layers[:-30]:  # Keep the first layers frozen
        layer.trainable = False
    
    # Use simple float learning rate
    model.compile(
        optimizer=Adam(learning_rate=lr),  # Simple float learning rate
        loss='binary_crossentropy',
        metrics=[
            'accuracy', 
            tf.keras.metrics.AUC(name='auc'),
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    )
    
    return model

# %%
# Function to find the optimal threshold using the validation set
def find_optimal_threshold(model, val_ds):
    # Get predictions
    val_pred = model.predict(val_ds)
    
    # Get true labels
    val_true = np.concatenate([y for x, y in val_ds], axis=0)
    
    # Calculate ROC curve and find optimal threshold
    fpr, tpr, thresholds = roc_curve(val_true, val_pred)
    j_scores = tpr - fpr
    best_idx = np.argmax(j_scores)
    best_threshold = thresholds[best_idx]
    
    print(f"Optimal threshold: {best_threshold:.4f} (Youden's J = {j_scores[best_idx]:.4f})")
    print(f"At threshold {best_threshold:.4f}: TPR={tpr[best_idx]:.4f}, FPR={fpr[best_idx]:.4f}")
    
    return best_threshold

# %%
def evaluate_with_threshold(model, ds, threshold=0.5):
    # Get predictions
    pred = model.predict(ds)
    
    # Get true labels
    true = np.concatenate([y for x, y in ds], axis=0)
    
    # Apply threshold
    pred_binary = (pred > threshold).astype(int)
    
    # Calculate metrics
    acc = accuracy_score(true, pred_binary)
    auc = roc_auc_score(true, pred)
    precision = precision_score(true, pred_binary)
    recall = recall_score(true, pred_binary)
    f1 = f1_score(true, pred_binary)
    cm = confusion_matrix(true, pred_binary)
    
    # Calculate specificity
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)
    
    print(f"Accuracy: {acc:.4f}")
    print(f"AUC: {auc:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Confusion Matrix:\n{cm}")
    
    return {
        'accuracy': acc,
        'auc': auc,
        'precision': precision,
        'recall': recall,
        'specificity': specificity,
        'f1': f1,
        'confusion_matrix': cm,
        'predictions': pred,
        'threshold': threshold
    }

# %%
# Prepare Callbacks
os.makedirs("/kaggle/working/models", exist_ok=True)

def get_callbacks(name):
    return [
        # Stop training when validation loss doesn't improve for 15 epochs
        EarlyStopping(
            monitor='val_loss',
            patience=15,
            restore_best_weights=True,
            verbose=1
        ),
        # Save the best model during training
        ModelCheckpoint(
            f"/kaggle/working/models/{name}.keras",
            save_best_only=True,
            monitor='val_auc',
            mode='max',
            verbose=1
        ),
        # Reduce learning rate when validation loss plateaus
        ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.2,
            patience=5,
            min_lr=1e-6,
            verbose=1
        )
    ]

# %%
models_to_train = {
    # "VGG16": VGG16
    "ResNet50": ResNet50
    # "DenseNet121": DenseNet121,
    # "EfficientNetB3": EfficientNetB3  
}

# %%
# Store training histories and model results
history_dict = {}
model_results = {}
all_trained_models = {}

# %%
for name, model_fn in models_to_train.items():
    print(f"\n{'='*50}")
    print(f"Training {name}...")
    print(f"{'='*50}")
    
    # Build model
    model, base_model = build_improved_model(model_fn, name=name)
    
    print(f"Initial training with frozen base layers...")
    # Phase 1: Train with frozen base model
    history1 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=30,  # Initial training epochs
        class_weight=class_weight_dict,
        callbacks=get_callbacks(f"{name}_phase1"),
        verbose=2
    )
    
    # Phase 2: Fine-tuning with unfrozen layers
    print(f"\nFine-tuning with unfrozen layers...")
    model = unfreeze_model(model, base_model, lr=1e-5)
    
    history2 = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=50,  # Fine-tuning epochs
        class_weight=class_weight_dict,
        callbacks=get_callbacks(f"{name}_phase2"),
        verbose=2
    )
    
    # Find optimal threshold
    print("\nFinding optimal threshold...")
    optimal_threshold = find_optimal_threshold(model, val_ds)
    
    # Evaluate model on test set with optimal threshold
    print("\nEvaluating on test set...")
    test_results = evaluate_with_threshold(model, test_ds, threshold=optimal_threshold)
    model_results[name] = test_results
    
    # Save model
    model.save(f"{name}_trained_model.h5")
    print(f"Saved model: {name}_trained_model.h5")
    
    # Save training history
    combined_history = {
        'phase1': history1.history,
        'phase2': history2.history
    }
    history_dict[name] = combined_history
    with open(f"{name}_history.pkl", "wb") as f:
        pickle.dump(combined_history, f)
    print(f"Saved training history: {name}_history.pkl")
    
    # Store model for ensemble
    all_trained_models[name] = model
# Out:
# ==================================================
# Training ResNet50...
# ==================================================
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Initial training with frozen base layers...
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745410652.522805      91 service.cc:148] XLA service 0x7bd2e8014770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745410652.523411      91 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1745410654.508213      91 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745410660.709151      91 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_auc improved from -inf to 0.68677, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 75s - 135ms/step - accuracy: 0.5837 - auc: 0.6140 - loss: 0.7607 - precision: 0.6323 - recall: 0.6065 - val_accuracy: 0.6512 - val_auc: 0.6868 - val_loss: 0.6323 - val_precision: 0.6379 - val_recall: 0.8667 - learning_rate: 1.0000e-04
# Epoch 2/30
#
# Epoch 2: val_auc improved from 0.68677 to 0.72241, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.6250 - auc: 0.6707 - loss: 0.6863 - precision: 0.6684 - recall: 0.6507 - val_accuracy: 0.5415 - val_auc: 0.7224 - val_loss: 0.8245 - val_precision: 0.8403 - val_recall: 0.2197 - learning_rate: 1.0000e-04
# Epoch 3/30
#
# Epoch 3: val_auc improved from 0.72241 to 0.77782, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.6595 - auc: 0.7130 - loss: 0.6412 - precision: 0.6972 - recall: 0.6886 - val_accuracy: 0.4860 - val_auc: 0.7778 - val_loss: 1.3753 - val_precision: 0.9858 - val_recall: 0.0795 - learning_rate: 1.0000e-04
# Epoch 4/30
#
# Epoch 4: val_auc improved from 0.77782 to 0.80209, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 41s - 74ms/step - accuracy: 0.6630 - auc: 0.7224 - loss: 0.6307 - precision: 0.6992 - recall: 0.6947 - val_accuracy: 0.6956 - val_auc: 0.8021 - val_loss: 0.6841 - val_precision: 0.6577 - val_recall: 0.9474 - learning_rate: 1.0000e-04
# Epoch 5/30
#
# Epoch 5: val_auc did not improve from 0.80209
# 555/555 - 30s - 54ms/step - accuracy: 0.6768 - auc: 0.7378 - loss: 0.6151 - precision: 0.7128 - recall: 0.7047 - val_accuracy: 0.6544 - val_auc: 0.6897 - val_loss: 0.7842 - val_precision: 0.6376 - val_recall: 0.8816 - learning_rate: 1.0000e-04
# Epoch 6/30
#
# Epoch 6: val_auc did not improve from 0.80209
# 555/555 - 30s - 54ms/step - accuracy: 0.6835 - auc: 0.7470 - loss: 0.6046 - precision: 0.7163 - recall: 0.7165 - val_accuracy: 0.6914 - val_auc: 0.7534 - val_loss: 0.6083 - val_precision: 0.6553 - val_recall: 0.9428 - learning_rate: 1.0000e-04
# Epoch 7/30
#
# Epoch 7: val_auc improved from 0.80209 to 0.82335, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7051 - auc: 0.7733 - loss: 0.5744 - precision: 0.7373 - recall: 0.7324 - val_accuracy: 0.7492 - val_auc: 0.8233 - val_loss: 0.5308 - val_precision: 0.7102 - val_recall: 0.9296 - learning_rate: 1.0000e-04
# Epoch 8/30
#
# Epoch 8: val_auc did not improve from 0.82335
# 555/555 - 30s - 54ms/step - accuracy: 0.7057 - auc: 0.7756 - loss: 0.5734 - precision: 0.7356 - recall: 0.7377 - val_accuracy: 0.7431 - val_auc: 0.8198 - val_loss: 0.5199 - val_precision: 0.7125 - val_recall: 0.9045 - learning_rate: 1.0000e-04
# Epoch 9/30
#
# Epoch 9: val_auc did not improve from 0.82335
# 555/555 - 30s - 54ms/step - accuracy: 0.7124 - auc: 0.7817 - loss: 0.5621 - precision: 0.7423 - recall: 0.7422 - val_accuracy: 0.7017 - val_auc: 0.7958 - val_loss: 0.5552 - val_precision: 0.6659 - val_recall: 0.9336 - learning_rate: 1.0000e-04
# Epoch 10/30
#
# Epoch 10: val_auc did not improve from 0.82335
# 555/555 - 30s - 54ms/step - accuracy: 0.7134 - auc: 0.7862 - loss: 0.5577 - precision: 0.7450 - recall: 0.7393 - val_accuracy: 0.7460 - val_auc: 0.8232 - val_loss: 0.5084 - val_precision: 0.7101 - val_recall: 0.9205 - learning_rate: 1.0000e-04
# Epoch 11/30
#
# Epoch 11: val_auc did not improve from 0.82335
# 555/555 - 30s - 54ms/step - accuracy: 0.7188 - auc: 0.7942 - loss: 0.5481 - precision: 0.7486 - recall: 0.7468 - val_accuracy: 0.6860 - val_auc: 0.7142 - val_loss: 0.8283 - val_precision: 0.6465 - val_recall: 0.9645 - learning_rate: 1.0000e-04
# Epoch 12/30
#
# Epoch 12: val_auc improved from 0.82335 to 0.83571, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7221 - auc: 0.7982 - loss: 0.5433 - precision: 0.7519 - recall: 0.7490 - val_accuracy: 0.5475 - val_auc: 0.8357 - val_loss: 0.8957 - val_precision: 0.9825 - val_recall: 0.1922 - learning_rate: 1.0000e-04
# Epoch 13/30
#
# Epoch 13: val_auc did not improve from 0.83571
# 555/555 - 30s - 54ms/step - accuracy: 0.7275 - auc: 0.8051 - loss: 0.5343 - precision: 0.7575 - recall: 0.7523 - val_accuracy: 0.7221 - val_auc: 0.8013 - val_loss: 0.5761 - val_precision: 0.6958 - val_recall: 0.8913 - learning_rate: 1.0000e-04
# Epoch 14/30
#
# Epoch 14: val_auc did not improve from 0.83571
# 555/555 - 30s - 54ms/step - accuracy: 0.7333 - auc: 0.8143 - loss: 0.5230 - precision: 0.7631 - recall: 0.7570 - val_accuracy: 0.6847 - val_auc: 0.7723 - val_loss: 0.5580 - val_precision: 0.7045 - val_recall: 0.7489 - learning_rate: 1.0000e-04
# Epoch 15/30
#
# Epoch 15: val_auc did not improve from 0.83571
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 555/555 - 30s - 54ms/step - accuracy: 0.7353 - auc: 0.8134 - loss: 0.5222 - precision: 0.7639 - recall: 0.7607 - val_accuracy: 0.7451 - val_auc: 0.8006 - val_loss: 0.5607 - val_precision: 0.7231 - val_recall: 0.8799 - learning_rate: 1.0000e-04
# Epoch 16/30
#
# Epoch 16: val_auc improved from 0.83571 to 0.83999, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7294 - auc: 0.8140 - loss: 0.5209 - precision: 0.7578 - recall: 0.7567 - val_accuracy: 0.7476 - val_auc: 0.8400 - val_loss: 0.4727 - val_precision: 0.7560 - val_recall: 0.8084 - learning_rate: 2.0000e-05
# Epoch 17/30
#
# Epoch 17: val_auc improved from 0.83999 to 0.88091, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7388 - auc: 0.8218 - loss: 0.5123 - precision: 0.7648 - recall: 0.7680 - val_accuracy: 0.7904 - val_auc: 0.8809 - val_loss: 0.4291 - val_precision: 0.8234 - val_recall: 0.7946 - learning_rate: 2.0000e-05
# Epoch 18/30
#
# Epoch 18: val_auc did not improve from 0.88091
# 555/555 - 30s - 54ms/step - accuracy: 0.7386 - auc: 0.8225 - loss: 0.5111 - precision: 0.7675 - recall: 0.7623 - val_accuracy: 0.7798 - val_auc: 0.8747 - val_loss: 0.4288 - val_precision: 0.7808 - val_recall: 0.8415 - learning_rate: 2.0000e-05
# Epoch 19/30
#
# Epoch 19: val_auc improved from 0.88091 to 0.88621, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7433 - auc: 0.8247 - loss: 0.5087 - precision: 0.7729 - recall: 0.7645 - val_accuracy: 0.8076 - val_auc: 0.8862 - val_loss: 0.4128 - val_precision: 0.7980 - val_recall: 0.8770 - learning_rate: 2.0000e-05
# Epoch 20/30
#
# Epoch 20: val_auc did not improve from 0.88621
# 555/555 - 30s - 54ms/step - accuracy: 0.7440 - auc: 0.8281 - loss: 0.5047 - precision: 0.7708 - recall: 0.7701 - val_accuracy: 0.7827 - val_auc: 0.8836 - val_loss: 0.4205 - val_precision: 0.8162 - val_recall: 0.7878 - learning_rate: 2.0000e-05
# Epoch 21/30
#
# Epoch 21: val_auc did not improve from 0.88621
# 555/555 - 30s - 54ms/step - accuracy: 0.7429 - auc: 0.8294 - loss: 0.5031 - precision: 0.7718 - recall: 0.7654 - val_accuracy: 0.7830 - val_auc: 0.8663 - val_loss: 0.4395 - val_precision: 0.7859 - val_recall: 0.8398 - learning_rate: 2.0000e-05
# Epoch 22/30
#
# Epoch 22: val_auc improved from 0.88621 to 0.88975, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 55ms/step - accuracy: 0.7473 - auc: 0.8302 - loss: 0.5013 - precision: 0.7763 - recall: 0.7684 - val_accuracy: 0.7786 - val_auc: 0.8898 - val_loss: 0.4220 - val_precision: 0.8509 - val_recall: 0.7311 - learning_rate: 2.0000e-05
# Epoch 23/30
#
# Epoch 23: val_auc did not improve from 0.88975
# 555/555 - 30s - 54ms/step - accuracy: 0.7427 - auc: 0.8287 - loss: 0.5026 - precision: 0.7714 - recall: 0.7657 - val_accuracy: 0.7502 - val_auc: 0.8823 - val_loss: 0.4611 - val_precision: 0.8577 - val_recall: 0.6619 - learning_rate: 2.0000e-05
# Epoch 24/30
#
# Epoch 24: val_auc did not improve from 0.88975
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 555/555 - 30s - 54ms/step - accuracy: 0.7522 - auc: 0.8343 - loss: 0.4953 - precision: 0.7806 - recall: 0.7731 - val_accuracy: 0.8050 - val_auc: 0.8781 - val_loss: 0.4282 - val_precision: 0.7810 - val_recall: 0.9039 - learning_rate: 2.0000e-05
# Epoch 25/30
#
# Epoch 25: val_auc improved from 0.88975 to 0.89881, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7521 - auc: 0.8356 - loss: 0.4947 - precision: 0.7782 - recall: 0.7770 - val_accuracy: 0.8066 - val_auc: 0.8988 - val_loss: 0.4013 - val_precision: 0.8252 - val_recall: 0.8289 - learning_rate: 4.0000e-06
# Epoch 26/30
#
# Epoch 26: val_auc improved from 0.89881 to 0.89952, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7484 - auc: 0.8325 - loss: 0.4977 - precision: 0.7761 - recall: 0.7715 - val_accuracy: 0.8054 - val_auc: 0.8995 - val_loss: 0.3947 - val_precision: 0.8197 - val_recall: 0.8347 - learning_rate: 4.0000e-06
# Epoch 27/30
#
# Epoch 27: val_auc did not improve from 0.89952
# 555/555 - 30s - 54ms/step - accuracy: 0.7504 - auc: 0.8358 - loss: 0.4935 - precision: 0.7773 - recall: 0.7746 - val_accuracy: 0.8105 - val_auc: 0.8977 - val_loss: 0.3942 - val_precision: 0.8160 - val_recall: 0.8524 - learning_rate: 4.0000e-06
# Epoch 28/30
#
# Epoch 28: val_auc did not improve from 0.89952
# 555/555 - 30s - 54ms/step - accuracy: 0.7523 - auc: 0.8360 - loss: 0.4922 - precision: 0.7797 - recall: 0.7749 - val_accuracy: 0.8050 - val_auc: 0.8992 - val_loss: 0.3954 - val_precision: 0.8225 - val_recall: 0.8295 - learning_rate: 4.0000e-06
# Epoch 29/30
#
# Epoch 29: val_auc improved from 0.89952 to 0.90145, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7520 - auc: 0.8338 - loss: 0.4960 - precision: 0.7804 - recall: 0.7728 - val_accuracy: 0.8101 - val_auc: 0.9015 - val_loss: 0.3908 - val_precision: 0.8263 - val_recall: 0.8352 - learning_rate: 4.0000e-06
# Epoch 30/30
#
# Epoch 30: val_auc improved from 0.90145 to 0.90178, saving model to /kaggle/working/models/ResNet50_phase1.keras
# 555/555 - 31s - 56ms/step - accuracy: 0.7553 - auc: 0.8384 - loss: 0.4897 - precision: 0.7825 - recall: 0.7775 - val_accuracy: 0.8140 - val_auc: 0.9018 - val_loss: 0.3888 - val_precision: 0.8199 - val_recall: 0.8541 - learning_rate: 4.0000e-06
# Restoring model weights from the end of the best epoch: 30.
#
# Fine-tuning with unfrozen layers...
# Epoch 1/50
#
# Epoch 1: val_auc improved from -inf to 0.85724, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 101s - 181ms/step - accuracy: 0.6739 - auc: 0.7358 - loss: 0.6105 - precision: 0.7090 - recall: 0.7046 - val_accuracy: 0.7020 - val_auc: 0.8572 - val_loss: 0.5405 - val_precision: 0.8804 - val_recall: 0.5389 - learning_rate: 1.0000e-05
# Epoch 2/50
#
# Epoch 2: val_auc improved from 0.85724 to 0.86631, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 75ms/step - accuracy: 0.7279 - auc: 0.8048 - loss: 0.5385 - precision: 0.7630 - recall: 0.7430 - val_accuracy: 0.7680 - val_auc: 0.8663 - val_loss: 0.4535 - val_precision: 0.8103 - val_recall: 0.7626 - learning_rate: 1.0000e-05
# Epoch 3/50
#
# Epoch 3: val_auc improved from 0.86631 to 0.86658, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 75ms/step - accuracy: 0.7403 - auc: 0.8235 - loss: 0.5119 - precision: 0.7725 - recall: 0.7575 - val_accuracy: 0.7999 - val_auc: 0.8666 - val_loss: 0.4482 - val_precision: 0.7852 - val_recall: 0.8827 - learning_rate: 1.0000e-05
# Epoch 4/50
#
# Epoch 4: val_auc improved from 0.86658 to 0.87056, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 74ms/step - accuracy: 0.7524 - auc: 0.8356 - loss: 0.4971 - precision: 0.7833 - recall: 0.7688 - val_accuracy: 0.7620 - val_auc: 0.8706 - val_loss: 0.4595 - val_precision: 0.8313 - val_recall: 0.7191 - learning_rate: 1.0000e-05
# Epoch 5/50
#
# Epoch 5: val_auc did not improve from 0.87056
# 555/555 - 40s - 72ms/step - accuracy: 0.7556 - auc: 0.8413 - loss: 0.4900 - precision: 0.7861 - recall: 0.7719 - val_accuracy: 0.7527 - val_auc: 0.8536 - val_loss: 0.5277 - val_precision: 0.7152 - val_recall: 0.9251 - learning_rate: 1.0000e-05
# Epoch 6/50
#
# Epoch 6: val_auc improved from 0.87056 to 0.89071, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 74ms/step - accuracy: 0.7632 - auc: 0.8500 - loss: 0.4762 - precision: 0.7956 - recall: 0.7745 - val_accuracy: 0.7221 - val_auc: 0.8907 - val_loss: 0.4813 - val_precision: 0.9261 - val_recall: 0.5452 - learning_rate: 1.0000e-05
# Epoch 7/50
#
# Epoch 7: val_auc did not improve from 0.89071
# 555/555 - 40s - 71ms/step - accuracy: 0.7645 - auc: 0.8526 - loss: 0.4703 - precision: 0.7946 - recall: 0.7792 - val_accuracy: 0.6752 - val_auc: 0.8427 - val_loss: 0.6424 - val_precision: 0.8967 - val_recall: 0.4720 - learning_rate: 1.0000e-05
# Epoch 8/50
#
# Epoch 8: val_auc did not improve from 0.89071
# 555/555 - 39s - 71ms/step - accuracy: 0.7655 - auc: 0.8562 - loss: 0.4639 - precision: 0.7969 - recall: 0.7778 - val_accuracy: 0.7951 - val_auc: 0.8724 - val_loss: 0.4360 - val_precision: 0.7842 - val_recall: 0.8730 - learning_rate: 1.0000e-05
# Epoch 9/50
#
# Epoch 9: val_auc improved from 0.89071 to 0.89117, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 76ms/step - accuracy: 0.7742 - auc: 0.8635 - loss: 0.4545 - precision: 0.8032 - recall: 0.7884 - val_accuracy: 0.7534 - val_auc: 0.8912 - val_loss: 0.4612 - val_precision: 0.8973 - val_recall: 0.6299 - learning_rate: 1.0000e-05
# Epoch 10/50
#
# Epoch 10: val_auc did not improve from 0.89117
# 555/555 - 39s - 71ms/step - accuracy: 0.7674 - auc: 0.8618 - loss: 0.4555 - precision: 0.8009 - recall: 0.7761 - val_accuracy: 0.6541 - val_auc: 0.8328 - val_loss: 0.6748 - val_precision: 0.8981 - val_recall: 0.4285 - learning_rate: 1.0000e-05
# Epoch 11/50
#
# Epoch 11: val_auc improved from 0.89117 to 0.90676, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 76ms/step - accuracy: 0.7743 - auc: 0.8683 - loss: 0.4454 - precision: 0.8053 - recall: 0.7854 - val_accuracy: 0.7888 - val_auc: 0.9068 - val_loss: 0.3944 - val_precision: 0.8750 - val_recall: 0.7248 - learning_rate: 1.0000e-05
# Epoch 12/50
#
# Epoch 12: val_auc did not improve from 0.90676
# 555/555 - 39s - 71ms/step - accuracy: 0.7842 - auc: 0.8751 - loss: 0.4355 - precision: 0.8151 - recall: 0.7930 - val_accuracy: 0.7549 - val_auc: 0.8394 - val_loss: 0.5420 - val_precision: 0.7428 - val_recall: 0.8576 - learning_rate: 1.0000e-05
# Epoch 13/50
#
# Epoch 13: val_auc improved from 0.90676 to 0.91469, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 76ms/step - accuracy: 0.7776 - auc: 0.8697 - loss: 0.4425 - precision: 0.8072 - recall: 0.7901 - val_accuracy: 0.8108 - val_auc: 0.9147 - val_loss: 0.3578 - val_precision: 0.8554 - val_recall: 0.7952 - learning_rate: 1.0000e-05
# Epoch 14/50
#
# Epoch 14: val_auc did not improve from 0.91469
# 555/555 - 39s - 71ms/step - accuracy: 0.7791 - auc: 0.8747 - loss: 0.4350 - precision: 0.8094 - recall: 0.7901 - val_accuracy: 0.7996 - val_auc: 0.8857 - val_loss: 0.4077 - val_precision: 0.7998 - val_recall: 0.8547 - learning_rate: 1.0000e-05
# Epoch 15/50
#
# Epoch 15: val_auc did not improve from 0.91469
# 555/555 - 40s - 72ms/step - accuracy: 0.7834 - auc: 0.8790 - loss: 0.4275 - precision: 0.8153 - recall: 0.7909 - val_accuracy: 0.6605 - val_auc: 0.8860 - val_loss: 0.6516 - val_precision: 0.9858 - val_recall: 0.3970 - learning_rate: 1.0000e-05
# Epoch 16/50
#
# Epoch 16: val_auc did not improve from 0.91469
# 555/555 - 39s - 71ms/step - accuracy: 0.7834 - auc: 0.8770 - loss: 0.4303 - precision: 0.8152 - recall: 0.7912 - val_accuracy: 0.7754 - val_auc: 0.9041 - val_loss: 0.4062 - val_precision: 0.8855 - val_recall: 0.6859 - learning_rate: 1.0000e-05
# Epoch 17/50
#
# Epoch 17: val_auc did not improve from 0.91469
# 555/555 - 40s - 73ms/step - accuracy: 0.7872 - auc: 0.8806 - loss: 0.4261 - precision: 0.8203 - recall: 0.7919 - val_accuracy: 0.6337 - val_auc: 0.8215 - val_loss: 1.0198 - val_precision: 0.9747 - val_recall: 0.3524 - learning_rate: 1.0000e-05
# Epoch 18/50
#
# Epoch 18: val_auc did not improve from 0.91469
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 555/555 - 39s - 71ms/step - accuracy: 0.7839 - auc: 0.8812 - loss: 0.4232 - precision: 0.8176 - recall: 0.7886 - val_accuracy: 0.6541 - val_auc: 0.8031 - val_loss: 0.7468 - val_precision: 0.8906 - val_recall: 0.4331 - learning_rate: 1.0000e-05
# Epoch 19/50
#
# Epoch 19: val_auc improved from 0.91469 to 0.92124, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 77ms/step - accuracy: 0.7937 - auc: 0.8890 - loss: 0.4102 - precision: 0.8254 - recall: 0.7993 - val_accuracy: 0.8235 - val_auc: 0.9212 - val_loss: 0.3449 - val_precision: 0.8359 - val_recall: 0.8507 - learning_rate: 2.0000e-06
# Epoch 20/50
#
# Epoch 20: val_auc improved from 0.92124 to 0.92580, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 74ms/step - accuracy: 0.7985 - auc: 0.8929 - loss: 0.4036 - precision: 0.8297 - recall: 0.8037 - val_accuracy: 0.8271 - val_auc: 0.9258 - val_loss: 0.3263 - val_precision: 0.8328 - val_recall: 0.8633 - learning_rate: 2.0000e-06
# Epoch 21/50
#
# Epoch 21: val_auc did not improve from 0.92580
# 555/555 - 40s - 71ms/step - accuracy: 0.8029 - auc: 0.8988 - loss: 0.3930 - precision: 0.8332 - recall: 0.8085 - val_accuracy: 0.8306 - val_auc: 0.9189 - val_loss: 0.3409 - val_precision: 0.8284 - val_recall: 0.8781 - learning_rate: 2.0000e-06
# Epoch 22/50
#
# Epoch 22: val_auc improved from 0.92580 to 0.92621, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 73ms/step - accuracy: 0.8043 - auc: 0.8999 - loss: 0.3902 - precision: 0.8362 - recall: 0.8073 - val_accuracy: 0.8271 - val_auc: 0.9262 - val_loss: 0.3274 - val_precision: 0.8252 - val_recall: 0.8753 - learning_rate: 2.0000e-06
# Epoch 23/50
#
# Epoch 23: val_auc did not improve from 0.92621
# 555/555 - 39s - 71ms/step - accuracy: 0.8038 - auc: 0.9001 - loss: 0.3894 - precision: 0.8379 - recall: 0.8039 - val_accuracy: 0.8181 - val_auc: 0.9144 - val_loss: 0.3548 - val_precision: 0.8350 - val_recall: 0.8398 - learning_rate: 2.0000e-06
# Epoch 24/50
#
# Epoch 24: val_auc did not improve from 0.92621
# 555/555 - 39s - 70ms/step - accuracy: 0.8061 - auc: 0.9018 - loss: 0.3869 - precision: 0.8366 - recall: 0.8108 - val_accuracy: 0.8204 - val_auc: 0.9159 - val_loss: 0.3514 - val_precision: 0.8239 - val_recall: 0.8621 - learning_rate: 2.0000e-06
# Epoch 25/50
#
# Epoch 25: val_auc did not improve from 0.92621
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1e-06.
# 555/555 - 40s - 71ms/step - accuracy: 0.8100 - auc: 0.9035 - loss: 0.3840 - precision: 0.8407 - recall: 0.8135 - val_accuracy: 0.8287 - val_auc: 0.9250 - val_loss: 0.3384 - val_precision: 0.8659 - val_recall: 0.8198 - learning_rate: 2.0000e-06
# Epoch 26/50
#
# Epoch 26: val_auc improved from 0.92621 to 0.92975, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 73ms/step - accuracy: 0.8096 - auc: 0.9051 - loss: 0.3801 - precision: 0.8410 - recall: 0.8122 - val_accuracy: 0.8379 - val_auc: 0.9297 - val_loss: 0.3180 - val_precision: 0.8326 - val_recall: 0.8879 - learning_rate: 1.0000e-06
# Epoch 27/50
#
# Epoch 27: val_auc improved from 0.92975 to 0.93143, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 74ms/step - accuracy: 0.8124 - auc: 0.9065 - loss: 0.3778 - precision: 0.8445 - recall: 0.8136 - val_accuracy: 0.8322 - val_auc: 0.9314 - val_loss: 0.3147 - val_precision: 0.8296 - val_recall: 0.8799 - learning_rate: 1.0000e-06
# Epoch 28/50
#
# Epoch 28: val_auc did not improve from 0.93143
# 555/555 - 39s - 70ms/step - accuracy: 0.8101 - auc: 0.9069 - loss: 0.3763 - precision: 0.8432 - recall: 0.8103 - val_accuracy: 0.8360 - val_auc: 0.9314 - val_loss: 0.3139 - val_precision: 0.8416 - val_recall: 0.8696 - learning_rate: 1.0000e-06
# Epoch 29/50
#
# Epoch 29: val_auc did not improve from 0.93143
# 555/555 - 39s - 70ms/step - accuracy: 0.8136 - auc: 0.9095 - loss: 0.3722 - precision: 0.8440 - recall: 0.8169 - val_accuracy: 0.8376 - val_auc: 0.9311 - val_loss: 0.3185 - val_precision: 0.8273 - val_recall: 0.8959 - learning_rate: 1.0000e-06
# Epoch 30/50
#
# Epoch 30: val_auc improved from 0.93143 to 0.93256, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 73ms/step - accuracy: 0.8142 - auc: 0.9090 - loss: 0.3724 - precision: 0.8439 - recall: 0.8184 - val_accuracy: 0.8322 - val_auc: 0.9326 - val_loss: 0.3108 - val_precision: 0.8402 - val_recall: 0.8633 - learning_rate: 1.0000e-06
# Epoch 31/50
#
# Epoch 31: val_auc improved from 0.93256 to 0.93387, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 41s - 75ms/step - accuracy: 0.8157 - auc: 0.9100 - loss: 0.3712 - precision: 0.8473 - recall: 0.8169 - val_accuracy: 0.8347 - val_auc: 0.9339 - val_loss: 0.3090 - val_precision: 0.8482 - val_recall: 0.8570 - learning_rate: 1.0000e-06
# Epoch 32/50
#
# Epoch 32: val_auc did not improve from 0.93387
# 555/555 - 39s - 70ms/step - accuracy: 0.8164 - auc: 0.9114 - loss: 0.3679 - precision: 0.8479 - recall: 0.8175 - val_accuracy: 0.8350 - val_auc: 0.9315 - val_loss: 0.3147 - val_precision: 0.8322 - val_recall: 0.8822 - learning_rate: 1.0000e-06
# Epoch 33/50
#
# Epoch 33: val_auc did not improve from 0.93387
# 555/555 - 39s - 71ms/step - accuracy: 0.8186 - auc: 0.9126 - loss: 0.3657 - precision: 0.8511 - recall: 0.8180 - val_accuracy: 0.8376 - val_auc: 0.9321 - val_loss: 0.3118 - val_precision: 0.8510 - val_recall: 0.8593 - learning_rate: 1.0000e-06
# Epoch 34/50
#
# Epoch 34: val_auc did not improve from 0.93387
# 555/555 - 39s - 70ms/step - accuracy: 0.8150 - auc: 0.9104 - loss: 0.3697 - precision: 0.8447 - recall: 0.8189 - val_accuracy: 0.8392 - val_auc: 0.9296 - val_loss: 0.3217 - val_precision: 0.8253 - val_recall: 0.9027 - learning_rate: 1.0000e-06
# Epoch 35/50
#
# Epoch 35: val_auc improved from 0.93387 to 0.93754, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 75ms/step - accuracy: 0.8180 - auc: 0.9105 - loss: 0.3701 - precision: 0.8486 - recall: 0.8201 - val_accuracy: 0.8395 - val_auc: 0.9375 - val_loss: 0.2997 - val_precision: 0.8341 - val_recall: 0.8890 - learning_rate: 1.0000e-06
# Epoch 36/50
#
# Epoch 36: val_auc did not improve from 0.93754
# 555/555 - 39s - 70ms/step - accuracy: 0.8166 - auc: 0.9106 - loss: 0.3699 - precision: 0.8470 - recall: 0.8191 - val_accuracy: 0.8325 - val_auc: 0.9361 - val_loss: 0.3215 - val_precision: 0.9031 - val_recall: 0.7838 - learning_rate: 1.0000e-06
# Epoch 37/50
#
# Epoch 37: val_auc did not improve from 0.93754
# 555/555 - 40s - 71ms/step - accuracy: 0.8151 - auc: 0.9119 - loss: 0.3669 - precision: 0.8481 - recall: 0.8144 - val_accuracy: 0.8395 - val_auc: 0.9314 - val_loss: 0.3122 - val_precision: 0.8449 - val_recall: 0.8724 - learning_rate: 1.0000e-06
# Epoch 38/50
#
# Epoch 38: val_auc did not improve from 0.93754
# 555/555 - 39s - 70ms/step - accuracy: 0.8158 - auc: 0.9119 - loss: 0.3672 - precision: 0.8471 - recall: 0.8173 - val_accuracy: 0.8382 - val_auc: 0.9356 - val_loss: 0.3050 - val_precision: 0.8556 - val_recall: 0.8541 - learning_rate: 1.0000e-06
# Epoch 39/50
#
# Epoch 39: val_auc did not improve from 0.93754
# 555/555 - 39s - 71ms/step - accuracy: 0.8203 - auc: 0.9155 - loss: 0.3600 - precision: 0.8518 - recall: 0.8206 - val_accuracy: 0.8376 - val_auc: 0.9346 - val_loss: 0.3085 - val_precision: 0.8383 - val_recall: 0.8781 - learning_rate: 1.0000e-06
# Epoch 40/50
#
# Epoch 40: val_auc did not improve from 0.93754
# 555/555 - 39s - 70ms/step - accuracy: 0.8135 - auc: 0.9121 - loss: 0.3661 - precision: 0.8453 - recall: 0.8147 - val_accuracy: 0.8325 - val_auc: 0.9299 - val_loss: 0.3239 - val_precision: 0.8633 - val_recall: 0.8312 - learning_rate: 1.0000e-06
# Epoch 41/50
#
# Epoch 41: val_auc improved from 0.93754 to 0.93820, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 75ms/step - accuracy: 0.8188 - auc: 0.9149 - loss: 0.3605 - precision: 0.8498 - recall: 0.8202 - val_accuracy: 0.8437 - val_auc: 0.9382 - val_loss: 0.2990 - val_precision: 0.8342 - val_recall: 0.8982 - learning_rate: 1.0000e-06
# Epoch 42/50
#
# Epoch 42: val_auc improved from 0.93820 to 0.93866, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 75ms/step - accuracy: 0.8202 - auc: 0.9159 - loss: 0.3593 - precision: 0.8524 - recall: 0.8197 - val_accuracy: 0.8484 - val_auc: 0.9387 - val_loss: 0.2961 - val_precision: 0.8578 - val_recall: 0.8730 - learning_rate: 1.0000e-06
# Epoch 43/50
#
# Epoch 43: val_auc improved from 0.93866 to 0.94014, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 76ms/step - accuracy: 0.8170 - auc: 0.9151 - loss: 0.3601 - precision: 0.8493 - recall: 0.8170 - val_accuracy: 0.8472 - val_auc: 0.9401 - val_loss: 0.2943 - val_precision: 0.8450 - val_recall: 0.8890 - learning_rate: 1.0000e-06
# Epoch 44/50
#
# Epoch 44: val_auc did not improve from 0.94014
# 555/555 - 39s - 71ms/step - accuracy: 0.8201 - auc: 0.9159 - loss: 0.3603 - precision: 0.8515 - recall: 0.8205 - val_accuracy: 0.8478 - val_auc: 0.9384 - val_loss: 0.3019 - val_precision: 0.8346 - val_recall: 0.9068 - learning_rate: 1.0000e-06
# Epoch 45/50
#
# Epoch 45: val_auc did not improve from 0.94014
# 555/555 - 40s - 72ms/step - accuracy: 0.8196 - auc: 0.9152 - loss: 0.3606 - precision: 0.8533 - recall: 0.8172 - val_accuracy: 0.8379 - val_auc: 0.9345 - val_loss: 0.3125 - val_precision: 0.8699 - val_recall: 0.8341 - learning_rate: 1.0000e-06
# Epoch 46/50
#
# Epoch 46: val_auc did not improve from 0.94014
# 555/555 - 39s - 70ms/step - accuracy: 0.8197 - auc: 0.9175 - loss: 0.3549 - precision: 0.8505 - recall: 0.8212 - val_accuracy: 0.8443 - val_auc: 0.9370 - val_loss: 0.3009 - val_precision: 0.8508 - val_recall: 0.8741 - learning_rate: 1.0000e-06
# Epoch 47/50
#
# Epoch 47: val_auc improved from 0.94014 to 0.94223, saving model to /kaggle/working/models/ResNet50_phase2.keras
# 555/555 - 42s - 75ms/step - accuracy: 0.8216 - auc: 0.9159 - loss: 0.3598 - precision: 0.8542 - recall: 0.8203 - val_accuracy: 0.8494 - val_auc: 0.9422 - val_loss: 0.2899 - val_precision: 0.8580 - val_recall: 0.8747 - learning_rate: 1.0000e-06
# Epoch 48/50
#
# Epoch 48: val_auc did not improve from 0.94223
# 555/555 - 39s - 70ms/step - accuracy: 0.8252 - auc: 0.9195 - loss: 0.3523 - precision: 0.8564 - recall: 0.8250 - val_accuracy: 0.8558 - val_auc: 0.9390 - val_loss: 0.3005 - val_precision: 0.8776 - val_recall: 0.8616 - learning_rate: 1.0000e-06
# Epoch 49/50
#
# Epoch 49: val_auc did not improve from 0.94223
# 555/555 - 39s - 71ms/step - accuracy: 0.8201 - auc: 0.9167 - loss: 0.3571 - precision: 0.8534 - recall: 0.8180 - val_accuracy: 0.8459 - val_auc: 0.9386 - val_loss: 0.2999 - val_precision: 0.8588 - val_recall: 0.8661 - learning_rate: 1.0000e-06
# Epoch 50/50
#
# Epoch 50: val_auc did not improve from 0.94223
# 555/555 - 39s - 70ms/step - accuracy: 0.8208 - auc: 0.9157 - loss: 0.3595 - precision: 0.8530 - recall: 0.8201 - val_accuracy: 0.8408 - val_auc: 0.9416 - val_loss: 0.3013 - val_precision: 0.8945 - val_recall: 0.8101 - learning_rate: 1.0000e-06
# Restoring model weights from the end of the best epoch: 47.
#
# Finding optimal threshold...
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 15s 99ms/step
# Optimal threshold: 0.5752 (Youden's J = 0.7046)
# At threshold 0.5752: TPR=0.8352, FPR=0.1306
#
# Evaluating on test set...
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step
# Accuracy: 0.8573
# AUC: 0.9475
# Precision: 0.9010
# Recall (Sensitivity): 0.8362
# Specificity: 0.8840
# F1 Score: 0.8674
# Confusion Matrix:
# [[1441  189]
#  [ 337 1720]]
# Saved model: ResNet50_trained_model.h5
# Saved training history: ResNet50_history.pkl
